# %%
import requests
from bs4 import BeautifulSoup
from multiprocessing.dummy import Pool
import time
import shutil
import re
import os
import json
import string
import glob

# %%
BASE_URL = 'https://www.pro-football-reference.com{0}'
PLAYER_LIST_URL = 'https://www.pro-football-reference.com/players/{0}'
PLAYER_PROFILE_URL = 'https://www.pro-football-reference.com/players/{0}/{1}'
PLAYER_GAMELOG_URL = 'https://www.pro-football-reference.com/players/{0}/{1}/gamelog/{2}'

HEADERS = {
    'user-agent': ('Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/48.0.2564.109 Safari/537.36')
}

PROFILE_DIR = 'profile_data'
STATS_DIR = 'stats_data'

# %%
class Scraper():
    """Scraper for pro-football-reference.com to collect NFL player stats"""

    def __init__(self, letters_to_scrape=['A'], num_jobs=1, clear_old_data=True, first_player_id=1):
        """Initialize the scraper to get player stats
                Args:
                    - letters_to_scrape (str[]): The site sorts players by the first letter of their
                      last name. This array tells the scraper which letters to scrape data for.
                    - num_jobs (int): Number of concurrent jobs the scraper should run. While Python
                      can't multi-thread, it can manage multiple processes at once, which allows it to
                      utilize time spent waiting for the server to respond.
                    - clear_old_data (boolean): Whether or not the data file should be wiped before
                      starting the scrape.
                    - first_player_id (int): The first ID for a player (set if you are rerunning to avoid duplicates)
                Returns:
                    None
        """
        self.letters_to_scrape = [letter.upper() for letter in letters_to_scrape]
        self.num_jobs = num_jobs
        self.clear_old_data = clear_old_data
        self.session = requests.Session()
        self.start_time = time.time()
        self.cross_process_player_count = 0
        self.first_player_id = first_player_id

        if num_jobs > 1:
            self.multiprocessing = True
            self.worker_pool = Pool(num_jobs)
        else:
            self.multiprocessing = False

    def scrape_site(self):
        """Pool workers to scrape players by first letter of last name"""
        if self.clear_old_data:
            self.clear_data()
        player_id = self.first_player_id
        for letter in self.letters_to_scrape:
            player_profile_urls = self.get_players_for_letter(letter)
            for player_profile_url in player_profile_urls:
                player = Player(player_id, player_profile_url, self)
                try:
                    player.scrape_profile()
                    player.scrape_player_stats()
                except (KeyboardInterrupt, SystemExit):
                    raise
                except:
                    print('There was a problem parsing stats for {}'.format(player_profile_url))
                    continue
                self.save_player_profile(player.profile)
                self.save_player_game_stats(player.game_stats, player.player_id, player.profile['name'])
                player_id += 1
        self.condense_data()

    def condense_data(self):
        """Condense data into two files, a profile file and a stats file"""
        print('Condensing Data...')
        condensed_profile_data = []
        all_profile_files = glob.glob('{}/*.json'.format(PROFILE_DIR))
        for file in all_profile_files:
            with open(file, 'rb') as fin:
                condensed_profile_data.append(json.load(fin))
        print('{} player profiles condensed'.format(len(condensed_profile_data)))
        filename = 'profiles_{}.json'.format(time.time())
        with open(filename, 'w') as fout:
            json.dump(condensed_profile_data, fout)

        condensed_game_data = []
        all_game_files = glob.glob('{}/*.json'.format(STATS_DIR))
        for file in all_game_files:
            with open(file, 'rb') as fin:
                condensed_game_data += json.load(fin)
        print('{} player seasons condensed'.format(len(condensed_game_data)))
        filename = 'games_{}.json'.format(time.time())
        with open(filename, 'w') as fout:
            json.dump(condensed_game_data, fout)

    def save_player_profile(self, profile):
        """Save a player's profile as JSON
            Args:
                - profile (dict): Player profile data
            Return:
                None
        """
        filename = '{}/{}_{}.json'.format(PROFILE_DIR, profile['player_id'], profile['name'].replace(' ', '-'))
        try:
            os.makedirs(PROFILE_DIR)
        except OSError:
            pass
        with open(filename, 'w') as fout:
            json.dump(profile, fout)

    def save_player_game_stats(self, games, player_id, player_name):
        """Save a list of player games with stats info
            Args:
                - games (dict[]): List of game stats
                - player_id (int): ID of the player the games belong to
                - player_name (str): Name of the player the game stats belong to
            Return:
                None
        """
        filename = '{}/{}_{}.json'.format(STATS_DIR, player_id, player_name.replace(' ', '-'))
        try:
            os.makedirs(STATS_DIR)
        except OSError:
            pass
        with open(filename, 'w') as fout:
            json.dump(games, fout)

    def get_players_for_letter(self, letter):
        """Get a list of player links for a letter of the alphabet.
            Site organizes players by first letter of last name.
            Args:
                - letter (str): letter of the alphabet uppercased
            Returns:
                - player_links (str[]): the URLs to get player profiles
        """
        response = self.get_page(PLAYER_LIST_URL.format(letter))
        soup = BeautifulSoup(response.content, 'html.parser')

        players = soup.find('div', {'id': 'div_players'}).find_all('a')
        return [BASE_URL.format(player['href']) for player in players]

    def get_page(self, url, retry_count=0):
        """Use requests to get a page; retry when failures occur
            Args:
                - url (str): The URL of the page to make a GET request to
                - retry_count (int): Number of times the URL has already been requests
            Returns:
                - response (obj): The Requests response object
        """
        try:
            return self.session.get(url, headers=HEADERS)
        except (KeyboardInterrupt, SystemExit):
            raise
        except:
            retry_count += 1
            if retry_count <= 3:
                self.session = requests.Session()
                return self.get_page(url, retry_count)
            else:
                raise

    def clear_data(self):
        """Clear the data directories"""
        try:
            shutil.rmtree(PROFILE_DIR)
        except FileNotFoundError:
            pass
        try:
            shutil.rmtree(STATS_DIR)
        except FileNotFoundError:
            pass

# %%
class Player():
    """An NFL player"""

    def __init__(self, player_id, profile_url, scraper):
        """
            Args:
                - player_id (int): Unique ID for player
                - profile_url (str): URL to the player's profile
                - scraper (obj): instance of Scraper class
            Returns:
                None
        """
        self.player_id = player_id
        self.profile_url = profile_url
        self.scraper = scraper
        self.profile = {
            'player_id': player_id,
            'name': None,
            'position': None,
            'height': None,
            'weight': None,
            'current_team': None,
            'birth_date': None,
            'birth_place': None,
            'death_date': None,
            'college': None,
            'high_school': None,
            'draft_team': None,
            'draft_round': None,
            'draft_position': None,
            'draft_year': None,
            'current_salary': None,
            'hof_induction_year': None
        }
        self.seasons_with_stats = []
        self.game_stats = []

    def scrape_profile(self):
        """Scrape profile info for player"""
        response = self.scraper.get_page(self.profile_url)
        soup = BeautifulSoup(response.content, 'html.parser')

        profile_section = soup.find('div', {'id': 'meta'})
        self.profile['name'] = profile_section.find('h1', {'itemprop': 'name'}).contents[0]
        print('scaping {}'.format(self.profile['name']))

        profile_attributes = profile_section.find_all('p')
        current_attribute = 1
        num_attributes = len(profile_attributes)

        self.profile['position'] = profile_attributes[current_attribute].contents[2].split('\n')[0].split(' ')[1]
        current_attribute += 1

        height = profile_attributes[current_attribute].find('span', {'itemprop': 'height'})
        if height is not None:
            self.profile['height'] = height.contents[0]
        weight = profile_attributes[current_attribute].find('span', {'itemprop': 'weight'})
        if weight is not None:
            self.profile['weight'] = weight.contents[0].split('lb')[0]
        if height is not None or weight is not None:
            current_attribute += 1

        affiliation_section = profile_section.find('span', {'itemprop': 'affiliation'})
        if affiliation_section is not None:
            self.profile['current_team'] = affiliation_section.contents[0].contents[0]
            current_attribute += 1

        birth_date = profile_attributes[current_attribute].find('span', {'itemprop': 'birthDate'})
        if birth_date is not None:
            self.profile['birth_date'] = birth_date['data-birth']
        birth_place_section = profile_attributes[current_attribute].find('span', {'itemprop': 'birthPlace'}).contents
        try:
            self.profile['birth_place'] = re.split('\xa0', birth_place_section[0])[1] + ' ' + birth_place_section[1].contents[0]
        except IndexError:
            pass
        if birth_date is not None or len(birth_place_section) > 0:
            current_attribute += 1

        death_section = profile_section.find('span', {'itemprop': 'deathDate'})
        if death_section is not None:
            self.profile['death_date'] = death_section['data-death']
            current_attribute += 1

        if profile_attributes[current_attribute].contents[0].contents[0] == 'College':
            self.profile['college'] = profile_attributes[current_attribute].contents[2].contents[0]
            current_attribute += 1

        # Skip weighted career AV
        current_attribute += 1

        if ((current_attribute + 1) <= num_attributes) and profile_attributes[current_attribute].contents[0].contents[0] == 'High School':
            self.profile['high_school'] = profile_attributes[current_attribute].contents[2].contents[0] + ', ' + profile_attributes[current_attribute].contents[4].contents[0]
            current_attribute += 1

        if ((current_attribute + 1) <= num_attributes) and profile_attributes[current_attribute].contents[0].contents[0] == 'Draft':
            self.profile['draft_team'] = profile_attributes[current_attribute].contents[2].contents[0]
            draft_info = profile_attributes[current_attribute].contents[3].split(' ')
            self.profile['draft_round'] = re.findall(r'\d+', draft_info[3])[0]
            self.profile['draft_position'] = re.findall(r'\d+', draft_info[5])[0]
            self.profile['draft_year'] = re.findall(r'\d+', profile_attributes[current_attribute].contents[4].contents[0])[0]
            current_attribute += 1

        if ((current_attribute + 1) <= num_attributes) and profile_attributes[current_attribute].contents[0].contents[0] == 'Current cap hit':
            profile_attributes[current_attribute].contents
            self.profile['current_salary'] = profile_attributes[current_attribute].contents[2].contents[0]
            current_attribute += 1

        if ((current_attribute + 1) <= num_attributes) and profile_attributes[current_attribute].contents[0].contents[0] == 'Hall of fame':
            self.profile['hof_induction_year'] = profile_attributes[current_attribute].contents[2].contents[0]
            current_attribute += 1

        self.seasons_with_stats = self.get_seasons_with_stats(soup)

    def scrape_player_stats(self):
        """Scrape the stats for all available games for a player"""
        for season in self.seasons_with_stats:
            if season['year'] == 'Career' or season['year'] == 'Postseason':
                continue
            self.scrape_season_gamelog(season['gamelog_url'], season['year'])

    def scrape_season_gamelog(self, gamelog_url, year):
        """Scrape player stats for a given year
            Args:
                - gamelog_url (str): URL to the stats for a given year
                - year (int): The year the stats are for
            Returns:
                - stats (dict): All of the player's stats for that year
        """
        response = self.scraper.get_page(gamelog_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        regular_season_table = soup.find('table', {'id': 'stats'})
        if regular_season_table is None:
            return False
        games = regular_season_table.find('tbody').find_all('tr')

        playoff_table = soup.find('table', {'id': 'stats_playoffs'})
        if playoff_table is not None:
            games += playoff_table.find('tbody').find_all('tr')

        for game in games:
            stats = self.make_player_game_stats(self.player_id, year)
            stats['game_id'] = game.find('td', {'data-stat': 'game_date'}).find('a', href=True)['href'].replace('/boxscores/', '').replace('.htm', '')
            stats['date'] = game.find('td', {'data-stat': 'game_date'}).contents[0].contents[0]
            stats['game_number'] = game.find('td', {'data-stat': 'game_num'}).contents[0]
            stats['age'] = game.find('td', {'data-stat': 'age'}).contents[0]
            stats['team'] = game.find('td', {'data-stat': 'team'}).contents[0].contents[0]
            if game.find('td', {'data-stat': 'game_location'}).contents == ['@']:
                stats['game_location'] = 'A'
            elif game.find('td', {'data-stat': 'game_location'}).contents == ['N']:
                stats['game_location'] = 'N'
            else:
                stats['game_location'] = 'H'
            stats['opponent'] = game.find('td', {'data-stat': 'opp'}).contents[0].contents[0]
            result = game.find('td', {'data-stat': 'game_result'}).contents[0].contents[0]
            stats['game_won'] = (result.split(' ')[0] == 'W')
            stats['player_team_score'] = result.split(' ')[1].split('-')[0]
            stats['opponent_score'] = result.split(' ')[1].split('-')[1]

            # Collect passing stats
            pass_attempts = game.find('td', {'data-stat': 'pass_cmp'})
            if pass_attempts is not None and len(pass_attempts) > 0:
                stats['passing_attempts'] = int(pass_attempts.contents[0])

            pass_completions = game.find('td', {'data-stat': 'pass_att'})
            if pass_completions is not None and len(pass_completions) > 0:
                stats['passing_completions'] = int(pass_completions.contents[0])

            pass_yards = game.find('td', {'data-stat': 'pass_yds'})
            if pass_yards is not None and len(pass_yards) > 0:
                stats['passing_yards'] = int(pass_yards.contents[0])

            pass_touchdowns = game.find('td', {'data-stat': 'pass_td'})
            if pass_touchdowns is not None and len(pass_touchdowns) > 0:
                stats['passing_touchdowns'] = int(pass_touchdowns.contents[0])

            pass_interceptions = game.find('td', {'data-stat': 'pass_int'})
            if pass_interceptions is not None and len(pass_interceptions) > 0:
                stats['passing_interceptions'] = int(pass_interceptions.contents[0])

            pass_rating = game.find('td', {'data-stat': 'pass_rating'})
            if pass_rating is not None and len(pass_rating) > 0:
                stats['passing_rating'] = float(pass_rating.contents[0])

            pass_sacks = game.find('td', {'data-stat': 'pass_sacked'})
            if pass_sacks is not None and len(pass_sacks) > 0:
                stats['passing_sacks'] = int(pass_sacks.contents[0])

            pass_sacks_yards_lost = game.find('td', {'data-stat': 'pass_sacked_yds'})
            if pass_sacks_yards_lost is not None and len(pass_sacks_yards_lost) > 0:
                stats['passing_sacks_yards_lost'] = int(pass_sacks_yards_lost.contents[0])

            # Collect rushing stats
            rushing_attempts = game.find('td', {'data-stat': 'rush_att'})
            if rushing_attempts is not None and len(rushing_attempts) > 0:
                stats['rushing_attempts'] = int(rushing_attempts.contents[0])

            rushing_yards = game.find('td', {'data-stat': 'rush_yds'})
            if rushing_yards is not None and len(rushing_yards) > 0:
                stats['rushing_yards'] = int(rushing_yards.contents[0])

            rushing_touchdowns = game.find('td', {'data-stat': 'rush_td'})
            if rushing_touchdowns is not None and len(rushing_touchdowns) > 0:
                stats['rushing_touchdowns'] = int(rushing_touchdowns.contents[0])

            # Collect receiving stats
            receiving_targets = game.find('td', {'data-stat': 'targets'})
            if receiving_targets is not None and len(receiving_targets) > 0:
                stats['receiving_targets'] = int(receiving_targets.contents[0])

            receiving_receptions = game.find('td', {'data-stat': 'rec'})
            if receiving_receptions is not None and len(receiving_receptions) > 0:
                stats['receiving_receptions'] = int(receiving_receptions.contents[0])

            receiving_yards = game.find('td', {'data-stat': 'rec_yds'})
            if receiving_yards is not None and len(receiving_yards) > 0:
                stats['receiving_yards'] = int(receiving_yards.contents[0])

            receiving_touchdowns = game.find('td', {'data-stat': 'rec_td'})
            if receiving_touchdowns is not None and len(receiving_touchdowns) > 0:
                stats['receiving_touchdowns'] = int(receiving_touchdowns.contents[0])

            # Collect kick return stats
            kick_return_attempts = game.find('td', {'data-stat': 'kick_ret'})
            if kick_return_attempts is not None and len(kick_return_attempts) > 0:
                stats['kick_return_attempts'] = int(kick_return_attempts.contents[0])

            kick_return_yards = game.find('td', {'data-stat': 'kick_ret_yds'})
            if kick_return_yards is not None and len(kick_return_yards) > 0:
                stats['kick_return_yards'] = int(kick_return_yards.contents[0])

            kick_return_touchdowns = game.find('td', {'data-stat': 'kick_ret_td'})
            if kick_return_touchdowns is not None and len(kick_return_touchdowns) > 0:
                stats['kick_return_touchdowns'] = int(kick_return_touchdowns.contents[0])

            # Collect punt return stats
            punt_return_attempts = game.find('td', {'data-stat': 'punt_ret'})
            if punt_return_attempts is not None and len(punt_return_attempts) > 0:
                stats['punt_return_attempts'] = int(punt_return_attempts.contents[0])

            punt_return_yards = game.find('td', {'data-stat': 'punt_ret_yds'})
            if punt_return_yards is not None and len(punt_return_yards) > 0:
                stats['punt_return_yards'] = int(punt_return_yards.contents[0])

            punt_return_touchdowns = game.find('td', {'data-stat': 'punt_ret_td'})
            if punt_return_touchdowns is not None and len(punt_return_touchdowns) > 0:
                stats['punt_return_touchdowns'] = int(punt_return_touchdowns.contents[0])

            # Collect defensive stats
            defense_sacks = game.find('td', {'data-stat': 'sacks'})
            if defense_sacks is not None and len(defense_sacks) > 0:
                stats['defense_sacks'] = float(defense_sacks.contents[0])

            defense_tackles = game.find('td', {'data-stat': 'tackles_solo'})
            if defense_tackles is not None and len(defense_tackles) > 0:
                stats['defense_tackles'] = int(defense_tackles.contents[0])

            defense_tackle_assists = game.find('td', {'data-stat': 'tackles_assists'})
            if defense_tackle_assists is not None and len(defense_tackle_assists) > 0:
                stats['defense_tackle_assists'] = int(defense_tackle_assists.contents[0])

            defense_interceptions = game.find('td', {'data-stat': 'def_int'})
            if defense_interceptions is not None and len(defense_interceptions) > 0:
                stats['defense_interceptions'] = int(defense_interceptions.contents[0])

            defense_interception_yards = game.find('td', {'data-stat': 'def_int_yds'})
            if defense_interception_yards is not None and len(defense_interception_yards) > 0:
                stats['defense_interception_yards'] = int(defense_interception_yards.contents[0])

            defense_safeties = game.find('td', {'data-stat': 'safety_md'})
            if defense_safeties is not None and len(defense_safeties) > 0:
                stats['defense_safeties'] = int(defense_safeties.contents[0])

            # Collect kicking stats
            point_after_attemps = game.find('td', {'data-stat': 'xpm'})
            if point_after_attemps is not None and len(point_after_attemps) > 0:
                stats['point_after_attemps'] = int(point_after_attemps.contents[0])

            point_after_makes = game.find('td', {'data-stat': 'xpa'})
            if point_after_makes is not None and len(point_after_makes) > 0:
                stats['point_after_makes'] = int(point_after_makes.contents[0])

            field_goal_attempts = game.find('td', {'data-stat': 'fga'})
            if field_goal_attempts is not None and len(field_goal_attempts) > 0:
                stats['field_goal_attempts'] = int(field_goal_attempts.contents[0])

            field_goal_makes = game.find('td', {'data-stat': 'fgm'})
            if field_goal_makes is not None and len(field_goal_makes) > 0:
                stats['field_goal_makes'] = int(field_goal_makes.contents[0])

            # Collect punting stats
            punting_attempts = game.find('td', {'data-stat': 'punt'})
            if punting_attempts is not None and len(punting_attempts) > 0:
                stats['punting_attempts'] = int(punting_attempts.contents[0])

            punting_yards = game.find('td', {'data-stat': 'punt_yds'})
            if punting_yards is not None and len(punting_yards) > 0:
                stats['punting_yards'] = int(punting_yards.contents[0])

            punting_blocked = game.find('td', {'data-stat': 'punt_blocked'})
            if punting_blocked is not None and len(punting_blocked) > 0:
                stats['punting_blocked'] = int(punting_blocked.contents[0])

            self.game_stats.append(stats)

    @staticmethod
    def make_player_game_stats(player_id, year):
        """Factory method to return possible stats to collect for a player in a game
            Args:
                - player_id (int): unique Id for the player
                - year (int): The year the stats are for
            Returns:
                - game_stats (dict): dictionary with game stats initialized
        """
        return {
            'player_id': player_id,
            'year': year,
            # General stats
            'game_id': None,
            'date': None,
            'game_number': None,
            'age': None,
            'team': None,
            'game_location': None,
            'opponent': None,
            'game_won': None,
            'player_team_score': 0,
            'opponent_score': 0,
            # Passing stats
            'passing_attempts': 0,
            'passing_completions': 0,
            'passing_yards': 0,
            'passing_rating': 0,
            'passing_touchdowns': 0,
            'passing_interceptions': 0,
            'passing_sacks': 0,
            'passing_sacks_yards_lost': 0,
            # Rushing stats
            'rushing_attempts': 0,
            'rushing_yards': 0,
            'rushing_touchdowns': 0,
            # Receiving stats
            'receiving_targets': 0,
            'receiving_receptions': 0,
            'receiving_yards': 0,
            'receiving_touchdowns': 0,
            # Kick return stats
            'kick_return_attempts': 0,
            'kick_return_yards': 0,
            'kick_return_touchdowns': 0,
            # PUnt return stats
            'punt_return_attempts': 0,
            'punt_return_yards': 0,
            'punt_return_touchdowns': 0,
            # Defense
            'defense_sacks': 0,
            'defense_tackles': 0,
            'defense_tackle_assists': 0,
            'defense_interceptions': 0,
            'defense_interception_yards': 0,
            'defense_interception_touchdowns': 0,
            'defense_safeties': 0,
            # Kicking
            'point_after_attemps': 0,
            'point_after_makes': 0,
            'field_goal_attempts': 0,
            'field_goal_makes': 0,
            # Punting
            'punting_attempts': 0,
            'punting_yards': 0,
            'punting_blocked': 0
        }

    def get_seasons_with_stats(self, profile_soup):
        """Scrape a list of seasons that has stats for the player
            Args:
                - profile_soup (obj): The BeautifulSoup object for the player profile page
            Returns:
                - seasons (dict[]): List of dictionaries with meta information about season stats
        """
        seasons = []
        gamelog_list = profile_soup.find('div', {'id': 'inner_nav'}).find_all('li')[1].find_all('li')
        if len(gamelog_list) > 0 and gamelog_list[0].contents[0].contents[0] == 'Career':
            for season in gamelog_list:
                seasons.append({
                    'year': season.contents[0].contents[0],
                    'gamelog_url': BASE_URL.format(season.contents[0]['href'])
                })
        return seasons

# %%
if __name__ == '__main__':
    letters_to_scrape = list(string.ascii_uppercase)
    nfl_scraper = Scraper(letters_to_scrape=letters_to_scrape, num_jobs=10, clear_old_data=False)

    nfl_scraper.scrape_site()
# Out:
# scaping Isaako Aaitui
# scaping Joe Abbey
# scaping Fay Abbott
# scaping Vince Abbott
# scaping Jared Abbrederis
# scaping Duke Abbruzzi
# scaping Mehdi Abdesmad
# scaping Karim Abdul-Jabbar
# scaping Isa Abdul-Quddus
# scaping Ameer Abdullah
# scaping Hamza Abdullah
# scaping Husain Abdullah
# scaping Khalid Abdullah
# scaping Rabih Abdullah
# scaping Rahim Abdullah
# scaping Fred Abel
# scaping Bud Abell
# scaping Walter Abercrombie
# scaping Cliff Aberson
# scaping Victor Abiamiri
# scaping Oday Aboushi
# scaping Clifton Abraham
# scaping Donnie Abraham
# scaping John Abraham
# scaping Robert Abraham
# scaping Danny Abramowicz
# scaping Sid Abramowitz
# scaping Bobby Abrams
# scaping Kevin Abrams
# scaping Nate Abrams
# scaping George Abramson
# scaping Dick Abrell
# scaping Ray Abruzzese
# scaping Frank Abruzzino
# scaping Dick Absher
# scaping Steve Ache
# scaping George Achica
# scaping Sneeze Achiu
# scaping Emmanuel Acho
# scaping Sam Acho
# scaping Bill Acker
# scaping Kenneth Acker
# scaping Rick Ackerman
# scaping Tom Ackerman
# scaping Ron Acks
# scaping Fred Acorn
# scaping Ed Adamchik
# scaping Mike Adamle
# scaping Tony Adamle
# scaping Aaron Adams
# scaping Andrew Adams
# scaping Anthony Adams
# scaping Bill Adams
# scaping Blue Adams
# scaping Bob Adams
# scaping Brent Adams
# scaping Charlie Adams
# scaping Chet Adams
# scaping Curtis Adams
# scaping D.J. Adams
# scaping Darvin Adams
# scaping Davante Adams
# scaping David Adams
# scaping Doug Adams
# scaping Earnest Adams
# scaping Flozell Adams
# scaping Gaines Adams
# scaping George Adams
# scaping Henry Adams
# scaping Jamal Adams
# scaping Jamar Adams
# scaping Jeff Adams
# scaping Jerell Adams
# scaping Joe Adams
# scaping John Adams
# scaping John Adams
# scaping Johnny Adams
# scaping Josh Adams
# scaping Julius Adams
# scaping Keith Adams
# scaping Kendrick Adams
# scaping Kris Adams
# scaping Kyle Adams
# scaping Matthew Adams
# scaping Michael Adams
# scaping Michael Adams
# scaping Mike Adams
# scaping Mike Adams
# scaping Mike Adams
# scaping Montravius Adams
# scaping Neal Adams
# scaping Pete Adams
# scaping Phillip Adams
# scaping Rodney Adams
# scaping Sam Adams
# scaping Sam Adams
# scaping Scott Adams
# scaping Stan Adams
# scaping Stefon Adams
# scaping Theo Adams
# scaping Titus Adams
# scaping Tom Adams
# scaping Tony Adams
# scaping Tyrell Adams
# scaping Vashone Adams
# scaping Verlin Adams
# scaping Willie Adams
# scaping Willis Adams
# scaping Ken Adamson
# scaping Levy Adcock
# scaping Jahleel Addae
# scaping Joseph Addai
# scaping Abe Addams
# scaping Herb Adderley
# scaping Bralon Addison
# scaping Mario Addison
# scaping Tom Addison
# scaping Nick Adduci
# scaping Quincy Adeboyejo
# scaping Olasunkanmi Adeniyi
# scaping Victor Adeyanju
# scaping Xavier Adibi
# scaping John Adickes
# scaping Mark Adickes
# scaping Jude Adjei-Barimah
# scaping Bob Adkins
# scaping Kevin Adkins
# scaping Margene Adkins
# scaping Roy Adkins
# scaping Sam Adkins
# scaping Spencer Adkins
# scaping James Adkisson
# scaping Daniel Adongo
# scaping Al Afalava
# scaping Erik Affholter
# scaping Dick Afflis
# scaping Ben Agajanian
# scaping Alex Agase
# scaping Louis Age
# scaping Mel Agee
# scaping Sam Agee
# scaping Tommie Agee
# scaping Nelson Agholor
# scaping Bob Agler
# scaping Jamal Agnew
# scaping Ray Agnew
# scaping Ray Agnew
# scaping Vince Agnew
# scaping Roberto Aguayo
# scaping Louie Aguiar
# scaping Joe Aguirre
# scaping C.J. Ah You
# scaping Chidi Ahanotu
# scaping Dan Ahern
# scaping Dave Ahrens
# scaping Tony Aiello
# scaping Danny Aiken
# scaping Kamar Aiken
# scaping Sam Aiken
# scaping Carl Aikens
# scaping Walt Aikens
# scaping Troy Aikman
# scaping Jim Ailinger
# scaping Charles Aiu
# scaping Victor Aiyewa
# scaping Jay Ajayi
# scaping Seyi Ajirotutu
# scaping Hakim Akbar
# scaping David Akers
# scaping Harold Akin
# scaping Len Akin
# scaping Al Akins
# scaping Chris Akins
# scaping Frank Akins
# scaping Jordan Akins
# scaping Mike Akiu
# scaping Anthony Alabi
# scaping Ikaika Alama-Francis
# scaping Dick Alban
# scaping Dom Albanese
# scaping Vannie Albanese
# scaping Tom Alberghini
# scaping Branden Albert
# scaping Frankie Albert
# scaping Sergio Albert
# scaping Trev Alberts
# scaping Art Albrecht
# scaping Ted Albrecht
# scaping Alex Albright
# scaping Bill Albright
# scaping Bryson Albright
# scaping Ethan Albright
# scaping Ira Albright
# scaping Vince Albritton
# scaping Zac Alcorn
# scaping Grady Alderman
# scaping John Alderton
# scaping Ki Aldrich
# scaping Allen Aldridge
# scaping Allen Aldridge
# scaping Bennie Aldridge
# scaping Jerry Aldridge
# scaping Kevin Aldridge
# scaping Lionel Aldridge
# scaping Melvin Aldridge
# scaping Arnold Ale
# scaping Ink Aleaga
# scaping Chas Alecxih
# scaping Keith Alex
# scaping Steve Alexakos
# scaping Adonis Alexander
# There was a problem parsing stats for https://www.pro-football-reference.com/players/A/AlexAd00.htm
# scaping Alvester Alexander
# scaping Brent Alexander
# scaping Bruce Alexander
# scaping Charles Alexander
# scaping D.J. Alexander
# scaping Dan Alexander
# scaping Dan Alexander
# scaping Danario Alexander
# scaping David Alexander
# scaping Derrick Alexander
# scaping Derrick Alexander
# scaping Doc Alexander
# scaping Dominique Alexander
# scaping Elijah Alexander
# scaping Eric Alexander
# scaping Frank Alexander
# scaping Gerald Alexander
# scaping Glenn Alexander
# scaping Harold Alexander
# scaping Jaire Alexander
# scaping Jeff Alexander
# scaping John Alexander
# scaping John Alexander
# scaping Kermit Alexander
# scaping Kevin Alexander
# scaping Kevin Alexander
# scaping Kwon Alexander
# scaping Lorenzo Alexander
# scaping Mackensie Alexander
# scaping Maurice Alexander
# scaping Mike Alexander
# scaping Mister Alexander
# scaping P.J. Alexander
# scaping Patrise Alexander
# scaping Ray Alexander
# scaping Robert Alexander
# scaping Roc Alexander
# scaping Rogers Alexander
# scaping Rufus Alexander
# scaping Shaun Alexander
# scaping Stephen Alexander
# scaping Vadal Alexander
# scaping Vincent Alexander
# scaping Willie Alexander
# scaping Alton Alexis
# scaping Rich Alexis
# scaping Ted Alflen
# scaping Julie Alfonse
# scaping Brian Alford
# scaping Bruce Alford
# scaping Bruce Alford
# scaping Darnell Alford
# scaping Dominic Alford
# scaping Gene Alford
# scaping Jay Alford
# scaping Lynwood Alford
# scaping Mario Alford
# scaping Mike Alford
# scaping Robert Alford
# scaping Warren Alfson
# scaping Charles Ali
# scaping Mo Alie-Cox
# scaping Tuineau Alipate
# scaping Don Allard
# scaping Raul Allegre
# scaping Andy Alleman
# scaping Anthony Allen
# scaping Anthony Allen
# scaping Antonio Allen
# scaping Armando Allen
# scaping Asher Allen
# scaping Beau Allen
# scaping Brian Allen
# scaping Brian Allen
# scaping Brian Allen
# scaping Brian Allen
# scaping Buddy Allen
# scaping Carl Allen
# scaping Carl Allen
# scaping Chase Allen
# scaping Chuck Allen
# scaping Cortez Allen
# scaping Dalva Allen
# scaping David Allen
# scaping Denicos Allen
# scaping Derek Allen
# scaping Don Allen
# scaping Doug Allen
# scaping Duane Allen
# scaping Dwayne Allen
# scaping Earl Allen
# scaping Ed Allen
# scaping Eddie Allen
# scaping Egypt Allen
# scaping Eric Allen
# scaping Ermal Allen
# scaping Gary Allen
# scaping George Allen
# scaping Gerry Allen
# scaping Grady Allen
# scaping Greg Allen
# scaping Harvey Allen
# scaping Ian Allen
# scaping Jackie Allen
# scaping Jake Allen
# scaping James Allen
# scaping James Allen
# scaping Jared Allen
# scaping Jason Allen
# scaping Javorius Allen
# scaping Jeff Allen
# scaping Jeff Allen
# scaping Jeff Allen
# scaping Jimmy Allen
# scaping Johnny Allen
# scaping Jonathan Allen
# scaping Josh Allen
# scaping Josh Allen
# scaping Keenan Allen
# scaping Kenderick Allen
# scaping Kevin Allen
# scaping Kyle Allen
# scaping Larry Allen
# scaping Lou Allen
# scaping Lynn Allen
# scaping Marcus Allen
# scaping Marcus Allen
# scaping Marvin Allen
# scaping Matt Allen
# scaping Nate Allen
# scaping Nate Allen
# scaping Patrick Allen
# scaping Rashaun Allen
# scaping Ricardo Allen
# scaping Roger Allen
# scaping Russell Allen
# scaping Ryan Allen
# scaping Taje Allen
# scaping Terry Allen
# scaping Torrence Allen
# scaping Tremayne Allen
# scaping Will Allen
# scaping Will Allen
# scaping Kurt Allerman
# scaping Ty Allert
# scaping Don Alley
# scaping Aundrae Allison
# scaping Geronimo Allison
# scaping Henry Allison
# scaping Jim Allison
# scaping Neely Allison
# scaping Buddy Alliston
# scaping Bob Allman
# scaping Brian Allred
# scaping Colin Allred
# scaping John Allred
# scaping Joe Allton
# scaping Jeff Alm
# scaping Beau Almodobar
# scaping Kiko Alonso
# scaping Gerald Alphin
# scaping Jon Alston
# scaping Lyneal Alston
# scaping Mack Alston
# scaping O'Brien Alston
# scaping Richard Alston
# scaping Mike Alstott
# scaping John Alt
# scaping Jim Althoff
# scaping Tyson Alualu
# scaping Wilson Alvarez
# scaping Steve Alvers
# scaping Steve Alvord
# scaping Tom Alward
# scaping Lance Alworth
# scaping Lyle Alzado
# scaping Eugene Amano
# scaping Jace Amaro
# scaping Ken Amato
# scaping Jonathon Amaya
# scaping John Amberg
# scaping Ashley Ambrose
# scaping Dick Ambrose
# scaping John Ambrose
# scaping Walt Ambrose
# scaping Alan Ameche
# scaping Danny Amendola
# scaping David Amerson
# scaping Glen Amerson
# scaping Dave Ames
# scaping Otis Amey
# scaping Vincent Amey
# scaping Richard Amman
# scaping Adrian Amos
# scaping Marty Amsler
# scaping Joe Amstutz
# scaping Prince Amukamara
# scaping Norm Amundsen
# scaping George Amundson
# scaping Vito Ananis
# scaping Rudy Andabaker
# scaping Kimble Anders
# scaping Jason Andersen
# scaping Morten Andersen
# scaping Stan Andersen
# scaping  Anderson
# scaping Alec Anderson
# scaping Alfred Anderson
# scaping Andre' Anderson
# scaping Anthony Anderson
# scaping Anthony Anderson
# scaping Antonio Anderson
# scaping Aric Anderson
# scaping Art Anderson
# scaping Bennie Anderson
# scaping Bill Anderson
# scaping Bill Anderson
# scaping Billy Anderson
# scaping Billy Guy Anderson
# scaping Bob Anderson
# scaping Bobby Anderson
# scaping Brad Anderson
# scaping Brandon Anderson
# scaping Bruce Anderson
# scaping Bryan Anderson
# scaping C.J. Anderson
# scaping Charlie Anderson
# scaping Charlie Anderson
# scaping Chet Anderson
# scaping Cliff Anderson
# scaping Colt Anderson
# scaping Courtney Anderson
# scaping Curtis Anderson
# scaping Curtis Anderson
# scaping Damien Anderson
# scaping Darren Anderson
# scaping David Anderson
# scaping Deon Anderson
# scaping Derek Anderson
# scaping Dick Anderson
# scaping Dick Anderson
# scaping Don Anderson
# scaping Donny Anderson
# scaping Dunstan Anderson
# scaping Dwayne Anderson
# scaping Dwight Anderson
# scaping Eddie Anderson
# scaping Eddie Anderson
# scaping Erick Anderson
# scaping Flipper Anderson
# scaping Fred Anderson
# scaping Gary Anderson
# scaping Gary Anderson
# scaping Gary Anderson
# scaping Henry Anderson
# scaping Herbie Anderson
# scaping Hunk Anderson
# scaping Jamaal Anderson
# scaping Jamal Anderson
# scaping James Anderson
# scaping Jason Anderson
# scaping Jerry Anderson
# scaping Jesse Anderson
# scaping Joe Anderson
# scaping John Anderson
# scaping Jonathan Anderson
# scaping Justin Anderson
# scaping Justin Anderson
# scaping Ken Anderson
# scaping Ken Anderson
# scaping Kim Anderson
# scaping Larry Anderson
# scaping Marcus Anderson
# scaping Mark Anderson
# scaping Marques Anderson
# scaping Max Anderson
# scaping Mel Anderson
# scaping Mike Anderson
# scaping Neal Anderson
# scaping Ockie Anderson
# scaping Ottis Anderson
# scaping Paul Anderson
# scaping Preston Anderson
# scaping Ralph Anderson
# scaping Ralph Anderson
# scaping Rashard Anderson
# scaping Ri'Shard Anderson
# scaping Richie Anderson
# scaping Rickey Anderson
# scaping Robby Anderson
# scaping Roger Anderson
# scaping Ronnie Anderson
# scaping Ryan Anderson
# scaping Scott Anderson
# scaping Scotty Anderson
# scaping Stephen Anderson
# scaping Stevie Anderson
# scaping Stuart Anderson
# scaping Sugarfoot Anderson
# scaping Taz Anderson
# scaping Terry Anderson
# scaping Tim Anderson
# scaping Vickey Ray Anderson
# scaping Vince Anderson
# scaping Warren Anderson
# scaping Will Anderson
# scaping William Anderson
# scaping Willie Anderson
# scaping Winnie Anderson
# scaping Zaire Anderson
# scaping Eric Andolsek
# scaping Steve Andrako
# scaping Troy Andrew
# scaping Al Andrews
# scaping Antonio Andrews
# scaping Billy Andrews
# scaping David Andrews
# scaping George Andrews
# scaping Jaby Andrews
# scaping John Andrews
# scaping John Andrews
# scaping Josh Andrews
# scaping Mark Andrews
# scaping Mitch Andrews
# scaping Ricky Andrews
# scaping Roy Andrews
# scaping Shawn Andrews
# scaping Stacy Andrews
# scaping Tom Andrews
# scaping William Andrews
# scaping Willie Andrews
# scaping George Andrie
# scaping Plato Andros
# scaping Teddy Andrulewicz
# scaping Lou Andrus
# scaping Shane Andrus
# scaping Sheldon Andrus
# scaping Sig Andrusking
# scaping Zenon Andrusyshyn
# scaping Joe Andruzzi
# scaping Charlie Ane
# scaping Charlie Ane
# scaping Mark Anelli
# scaping Jim Angelo
# scaping Bryan Anger
# scaping Pat Angerer
# scaping Elmer Angsman
# scaping Richard Angulo
# scaping Eli Ankou
# scaping Jason Ankrah
# scaping Scott Ankrom
# scaping Dunc Annan
# scaping Blake Annen
# scaping Sam Anno
# scaping Ezekiel Ansah
# scaping Charles Anthony
# scaping Cornelius Anthony
# scaping Reidel Anthony
# scaping Stephone Anthony
# scaping Terrence Anthony
# scaping Terry Anthony
# scaping Tyrone Anthony
# scaping Lionel Antoine
# scaping Glenn Antrum
# scaping Houston Antwine
# scaping Kenny Anunike
# scaping Chigbo Anunoby
# scaping Alex Anzalone
# scaping Steve Apke
# scaping Troy Apke
# scaping Chuck Apolskis
# scaping Ray Apolskis
# scaping Clarence Appelgran
# scaping Eli Apple
# scaping Jim Apple
# scaping Scott Appleton
# scaping Antwan Applewhite
# scaping Marger Apsit
# scaping Ben Apuna
# scaping Leo Araguz
# scaping Evan Arapostathis
# scaping Fred Arbanas
# scaping Hasson Arbubakrr
# scaping Charles Arbuckle
# scaping Emmanuel Arceneaux
# scaping Lester Archambeau
# scaping Brandon Archer
# scaping Dan Archer
# scaping David Archer
# scaping Dri Archer
# scaping Troy Archer
# scaping Ben Archibald
# scaping Mike Archie
# scaping Julie Archoska
# scaping Adam Archuleta
# scaping Billy Ard
# scaping Tony Ardizzone
# scaping Tony Arena
# scaping Javier Arenas
# scaping Joe Arenas
# scaping Arnie Arenz
# scaping Bob Argus
# scaping Gump Ariail
# scaping Jake Arians
# scaping Mike Ariey
# scaping Obed Ariri
# scaping David Arkin
# scaping Alex Armah
# scaping Thurston Armbrister
# scaping JoJuan Armour
# scaping Justin Armour
# scaping Phil Armour
# scaping Loyd Arms
# scaping Arik Armstead
# scaping Jessie Armstead
# scaping Terron Armstead
# scaping Adger Armstrong
# scaping Anthony Armstrong
# scaping Antonio Armstrong
# scaping Bill Armstrong
# scaping Bob Armstrong
# scaping Bruce Armstrong
# scaping Charlie Armstrong
# scaping Cornell Armstrong
# scaping Derick Armstrong
# scaping Dorance Armstrong Jr.
# scaping Graham Armstrong
# scaping Harvey Armstrong
# scaping Jimmy Armstrong
# scaping John Armstrong
# scaping John Armstrong
# scaping Neill Armstrong
# scaping Norris Armstrong
# scaping Otis Armstrong
# scaping Quincy Armstrong
# scaping Ray Armstrong
# scaping Ray-Ray Armstrong
# scaping Trace Armstrong
# scaping Tyji Armstrong
# scaping Al Arndt
# scaping Dick Arndt
# scaping Jim Arneson
# scaping Mark Arneson
# scaping Jon Arnett
# scaping Brian Arnfelt
# scaping Dan Arnold
# scaping David Arnold
# scaping Jahine Arnold
# scaping Jay Arnold
# scaping Jim Arnold
# scaping John Arnold
# scaping LeFrancis Arnold
# scaping Walt Arnold
# scaping Stanley Arnoux
# scaping Devin Aromashodu
# scaping Doug Aronson
# scaping John Arp
# scaping Adrian Arrington
# scaping J.J. Arrington
# scaping Kyle Arrington
# scaping LaVar Arrington
# scaping Rick Arrington
# scaping Chuck Arrobio
# scaping Elmer Arterburn
# scaping Gary Arthur
# scaping Mike Arthur
# scaping Cameron Artis-Payne
# scaping Corrie Artman
# scaping Rodney Artmore
# scaping Lee Artoe
# scaping Herman Arvie
# scaping Doug Asad
# scaping Jon Asamoah
# scaping Larry Asante
# scaping Willie Asbury
# scaping Darrel Aschbacher
# scaping Frank Aschenbrenner
# scaping Juddy Ash
# scaping Richard Ash
# scaping Bill Ashbaugh
# scaping Cliff Ashburn
# scaping Richard Ashe
# scaping Bob Asher
# scaping Jamie Asher
# scaping Walker Lee Ashley
# scaping Darryl Ashmore
# scaping Roger Ashmore
# scaping Josh Ashton
# scaping Tom Ashworth
# scaping Isaac Asiata
# scaping Johan Asiata
# scaping Matt Asiata
# scaping K.C. Asiodu
# scaping Joe Aska
# scaping Mike Askea
# scaping B.J. Askew
# scaping Matthias Askew
# scaping Nate Askew
# scaping Bert Askson
# scaping Jim Asmus
# scaping Nnamdi Asomugha
# scaping Ed Aspatore
# scaping Mark Asper
# scaping Les Asplundh
# scaping Jack Atchason
# scaping Burl Atcheson
# scaping Tim Atchison
# scaping Marcell Ateman
# scaping Bill Atessis
# scaping Pete Athas
# scaping Dale Atkeson
# scaping Baraka Atkins
# scaping Billy Atkins
# scaping Bob Atkins
# scaping Corey Atkins
# scaping Dave Atkins
# There was a problem parsing stats for https://www.pro-football-reference.com/players/A/AtkiDa00.htm
# scaping Doug Atkins
# scaping Gene Atkins
# scaping Geno Atkins
# scaping George Atkins
# scaping James Atkins
# scaping James Atkins
# scaping John Atkins
# scaping Kelvin Atkins
# scaping Larry Atkins
# scaping Pervis Atkins
# scaping Steve Atkins
# scaping Al Atkinson
# scaping Frank Atkinson
# scaping George Atkinson
# scaping George Atkinson
# scaping Jess Atkinson
# scaping Ricky Atkinson
# scaping O.J. Atogwe
# scaping Reggie Attache
# scaping Jeremiah Attaochu
# scaping Alex Atty
# scaping Steve Atwater
# scaping John Atwood
# scaping Josh Aubrey
# scaping Antony Auclair
# scaping Earl Audet
# scaping Dan Audick
# scaping Howie Auer
# scaping Jim Auer
# scaping Joe Auer
# scaping Scott Auer
# scaping Todd Auer
# scaping Dowe Aughtman
# scaping Sky August
# scaping Steve August
# scaping Gene Augusterfer
# scaping Mike Augustyniak
# scaping Chalmer Ault
# scaping David Aupiu
# scaping David Ausberry
# scaping Bill Austin
# scaping Billy Austin
# scaping Cliff Austin
# scaping Darrell Austin
# scaping Eric Austin
# scaping Hise Austin
# scaping Jim Austin
# scaping Kent Austin
# scaping Marvin Austin
# scaping Miles Austin
# scaping Ocie Austin
# scaping Raymond Austin
# scaping Reggie Austin
# scaping Rodney Austin
# scaping Tavon Austin
# scaping Terrence Austin
# scaping Thomas Austin
# scaping Billy Autrey
# scaping Darnell Autry
# scaping Denico Autry
# scaping Hank Autry
# scaping Troy Auzenne
# scaping Jason Avant
# scaping Chuck Avedisian
# scaping Bob Avellini
# scaping John Aveni
# scaping Anthony Averett
# scaping Sisto Averno
# scaping Don Avery
# scaping Donnie Avery
# scaping Genard Avery
# scaping Jim Avery
# scaping John Avery
# scaping Ken Avery
# scaping Steve Avery
# scaping Joe Avezzano
# scaping Butch Avinger
# scaping Cliff Avril
# scaping Robert Awalt
# scaping Adrian Awasom
# scaping Chidobe Awuzie
# scaping Brendon Ayanbadejo
# scaping Obafemi Ayanbadejo
# scaping Buddy Aydelette
# scaping Akeem Ayers
# scaping Demarcus Ayers
# scaping John Ayers
# scaping Marvin Ayers
# scaping Robert Ayers
# scaping Kole Ayi
# scaping Akin Ayodele
# scaping Remi Ayodele
# scaping Joe Azelby
# scaping Jerry Azumah
# scaping Mike Baab
# scaping Steve Baack
# scaping David Baas
# scaping Al Babartsky
# scaping Charlie Babb
# scaping Gene Babb
# scaping Harry Babcock
# scaping Sam Babcock
# scaping Bill Baber
# scaping Roderick Babers
# scaping Bob Babich
# scaping Jason Babin
# scaping Jonathan Babineaux
# scaping Jordan Babineaux
# scaping John Babinecz
# scaping Jeff Baca
# scaping Marty Baccaglio
# scaping Carl Bacchus
# scaping Joe Bachmaier
# scaping Jay Bachman
# scaping Ted Bachman
# scaping Rip Bachor
# scaping Kennard Backman
# scaping  Backnor
# scaping Jeff Backus
# scaping Coy Bacon
# scaping Frank Bacon
# scaping Waine Bacon
# scaping John Badaczewski
# scaping Rick Badanjek
# scaping Richard Badar
# scaping Johnson Bademosi
# scaping Brad Badger
# scaping Michael Badgley
# scaping Red Badgro
# scaping Steve Bagarus
# scaping Herm Bagby
# scaping Ed Bagdon
# scaping Billy Baggett
# scaping Curt Baham
# scaping Pete Bahan
# scaping Ken Bahnsen
# scaping Chris Bahr
# scaping Matt Bahr
# scaping Aaron Bailey
# scaping Allen Bailey
# scaping Alvin Bailey
# scaping Bill Bailey
# scaping Boss Bailey
# scaping Byron Bailey
# scaping Carlton Bailey
# scaping Champ Bailey
# scaping Clarence Bailey
# scaping Dan Bailey
# scaping David Bailey
# scaping Dion Bailey
# scaping Don Bailey
# scaping Edwin Bailey
# scaping Elmer Bailey
# scaping Eric Bailey
# scaping Harold Bailey
# scaping Henry Bailey
# scaping Howard Bailey
# scaping Jim Bailey
# scaping Jim Bailey
# scaping Johnny Bailey
# scaping Karsten Bailey
# scaping Larry Bailey
# scaping Mark Bailey
# scaping Monk Bailey
# scaping Patrick Bailey
# scaping Robert Bailey
# scaping Rodney Bailey
# scaping Russ Bailey
# scaping Stacey Bailey
# scaping Stedman Bailey
# scaping Teddy Bailey
# scaping Thomas Bailey
# scaping Tom Bailey
# scaping Victor Bailey
# scaping Bill Bain
# scaping Brandon Bair
# scaping Bill Baird
# scaping Al Baisi
# scaping Billy Bajema
# scaping Al Baker
# scaping Art Baker
# scaping Budda Baker
# scaping Bullet Baker
# scaping Charles Baker
# scaping Chase Baker
# scaping Chris Baker
# scaping Chris Baker
# scaping Conway Baker
# scaping Dallas Baker
# scaping Dave Baker
# scaping Ed Baker
# scaping Edwin Baker
# scaping Eugene Baker
# scaping Frank Baker
# scaping Jason Baker
# scaping Jerome Baker
# scaping Jerry Baker
# scaping Jesse Baker
# scaping John Baker
# scaping John Baker
# scaping John Baker
# scaping Johnny Baker
# scaping Jon Baker
# scaping Jon Baker
# scaping Josh Baker
# scaping Keith Baker
# scaping Larry Baker
# scaping Melvin Baker
# scaping Myron Baker
# scaping Ralph Baker
# scaping Rashad Baker
# scaping Robert Baker
# scaping Ron Baker
# scaping Ryan Baker
# scaping Sam Baker
# scaping Sam Baker
# scaping Sean Baker
# scaping Shannon Baker
# scaping Stephen Baker
# scaping Steven Baker
# scaping Terry Baker
# scaping Tim Baker
# scaping Tony Baker
# scaping Tony Baker
# scaping Wayne Baker
# scaping David Bakhtiari
# scaping Eric Bakhtiari
# scaping Jim Bakken
# scaping Ed Balatti
# scaping Frank Balazs
# scaping Lou Baldacci
# scaping Mike Baldassin
# scaping Brian Baldinger
# scaping Gary Baldinger
# scaping Rich Baldinger
# scaping Karl Baldischwiler
# scaping Daniel Baldridge
# scaping Alex Balducci
# scaping Al Baldwin
# scaping Bob Baldwin
# scaping Burr Baldwin
# scaping Cliff Baldwin
# scaping Don Baldwin
# scaping Doug Baldwin
# scaping Ervin Baldwin
# scaping George Baldwin
# scaping Jack Baldwin
# scaping Johnny Baldwin
# scaping Jonathan Baldwin
# scaping Keith Baldwin
# scaping Randy Baldwin
# scaping Tom Baldwin
# scaping Alan Ball
# scaping Dave Ball
# scaping Eric Ball
# scaping Jason Ball
# scaping Jerry Ball
# scaping Lance Ball
# scaping Larry Ball
# scaping Marcus Ball
# scaping Michael Ball
# scaping Montee Ball
# scaping Neiron Ball
# scaping Sam Ball
# scaping Kalen Ballage
# scaping Pat Ballage
# scaping Christian Ballard
# scaping Howard Ballard
# scaping Jake Ballard
# scaping Quinton Ballard
# scaping Vick Ballard
# scaping Lonnie Ballentine
# scaping Gary Ballman
# scaping Mike Ballou
# scaping Kentwan Balmer
# scaping Bob Balog
# scaping Mike Balogun
# scaping Vic Baltzell
# scaping Michael Bamiro
# scaping Steve Banas
# scaping John Banaszak
# scaping Pete Banaszak
# scaping Cas Banaszek
# scaping Hugh Bancroft
# scaping Romeo Bandison
# scaping Bruno Banducci
# scaping John Bandura
# scaping Don Bandy
# scaping Joey Banes
# scaping Herb Banet
# scaping Tony Banfield
# scaping Ben Bangs
# scaping Emil Banjavic
# scaping Chris Banjo
# scaping Ted Banker
# scaping Antonio Banks
# scaping Brandon Banks
# scaping Brandon Banks
# scaping Carl Banks
# scaping Chip Banks
# scaping Chris Banks
# scaping Chuck Banks
# scaping Estes Banks
# scaping Fred Banks
# scaping Gary Banks
# scaping Gordon Banks
# scaping Jason Banks
# scaping Johnthan Banks
# scaping Mike Banks
# scaping Robert Banks
# scaping Roy Banks
# scaping Tavian Banks
# scaping Tom Banks
# scaping Tony Banks
# scaping Willie Banks
# scaping Michael Bankston
# scaping Warren Bankston
# scaping Justin Bannan
# scaping Zach Banner
# scaping Alex Bannister
# scaping Bruce Bannon
# scaping Vince Banonis
# scaping Al Bansavage
# scaping Bradford Banta
# scaping Jack Banta
# scaping Tully Banta-Cain
# scaping Joe Banyard
# scaping Gary Barbaro
# scaping Roland Barbay
# scaping Joe Barbee
# scaping Ben Barber
# scaping Bob Barber
# scaping Chris Barber
# scaping Dominique Barber
# scaping Ernie Barber
# scaping Jim Barber
# scaping Kantroy Barber
# scaping Kurt Barber
# scaping Marion Barber
# scaping Marion Barber
# scaping Mark Barber
# scaping Michael Barber
# scaping Mike Barber
# scaping Mike Barber
# scaping Peyton Barber
# scaping Ronde Barber
# scaping Rudy Barber
# scaping Shawn Barber
# scaping Stew Barber
# scaping Tiki Barber
# scaping Pete Barbolak
# scaping Elmer Barbour
# scaping Allen Barbre
# scaping Chris Barclay
# scaping Don Barclay
# scaping Brandon Barden
# scaping Ramses Barden
# scaping John Barefield
# scaping Ken Barefoot
# scaping Ken Barfield
# scaping Adrian Baril
# scaping Carl Barisich
# scaping Bryan Barker
# scaping Chris Barker
# scaping Dick Barker
# scaping Ed Barker
# scaping Hub Barker
# scaping Leo Barker
# scaping Roy Barker
# scaping Tony Barker
# scaping Will Barker
# scaping Matt Barkley
# scaping Saquon Barkley
# scaping Ralph Barkman
# scaping Joe Barksdale
# scaping Rashad Barksdale
# scaping Rod Barksdale
# scaping Jerome Barkum
# scaping Lou Barle
# scaping Corey Barlow
# scaping Kevan Barlow
# scaping Reggie Barlow
# scaping George Barna
# scaping Brooks Barnard
# scaping Charles Barnard
# scaping Tom Barndt
# scaping Kenjon Barner
# scaping Adairius Barnes
# scaping Al Barnes
# scaping Antwan Barnes
# scaping Benny Barnes
# scaping Billy Ray Barnes
# scaping Brandon Barnes
# scaping Bruce Barnes
# scaping Charlie Barnes
# scaping Darian Barnes
# scaping Derrick Barnes
# scaping Earnest Barnes
# scaping Emery Barnes
# scaping Erich Barnes
# scaping Ernie Barnes
# scaping Gary Barnes
# scaping Jeff Barnes
# scaping Joe Barnes
# scaping Johnnie Barnes
# scaping Kevin Barnes
# scaping Khalif Barnes
# scaping Larry Barnes
# scaping Larry Barnes
# scaping Lew Barnes
# scaping Lionel Barnes
# scaping Marlon Barnes
# scaping Mike Barnes
# scaping Mike Barnes
# scaping Pat Barnes
# scaping Pete Barnes
# scaping Rashidi Barnes
# scaping Reggie Barnes
# scaping Rodrigo Barnes
# scaping Roosevelt Barnes
# scaping T.J. Barnes
# scaping Tavaris Barnes
# scaping Tim Barnes
# scaping Tomur Barnes
# scaping Walt Barnes
# scaping Walt Barnes
# scaping Bill Barnett
# scaping Buster Barnett
# scaping Calvin Barnett
# scaping Dean Barnett
# scaping Derek Barnett
# scaping Doug Barnett
# scaping Fred Barnett
# scaping Harlon Barnett
# scaping Nick Barnett
# scaping Oliver Barnett
# scaping Solon Barnett
# scaping Steve Barnett
# scaping Tim Barnett
# scaping Tom Barnett
# scaping Troy Barnett
# scaping Vincent Barnett
# scaping Eppie Barney
# scaping Lem Barney
# scaping Milton Barney
# scaping Tommy Barnhardt
# scaping Dan Barnhart
# scaping Roy Barni
# scaping Gary Barnidge
# scaping Eddie Barnikow
# scaping Len Barnum
# scaping Pete Barnum
# scaping Malcolm Barnwell
# scaping Anthony Barr
# scaping Dave Barr
# scaping Mike Barr
# scaping Shorty Barr
# scaping Terry Barr
# scaping Bob Barrabee
# scaping Nate Barragar
# scaping Napoleon Barrel
# scaping Alex Barrett
# scaping Bob Barrett
# scaping Dave Barrett
# scaping David Barrett
# scaping Emmett Barrett
# scaping Jan Barrett
# scaping Jean Barrett
# scaping Jeff Barrett
# scaping John Barrett
# scaping Johnny Barrett
# scaping Josh Barrett
# scaping Reggie Barrett
# scaping Shaquil Barrett
# scaping Sebastian Barrie
# scaping Sam Barrington
# scaping Tom Barrington
# scaping Alex Barron
# scaping Jim Barron
# scaping Mark Barron
# scaping Lamin Barrow
# scaping Micheal Barrow
# scaping Scott Barrows
# scaping Al Barry
# scaping Fred Barry
# scaping Kevin Barry
# scaping Norm Barry
# scaping Odell Barry
# scaping Paul Barry
# scaping Brad Bars
# scaping John Barsha
# scaping Steve Bartalo
# scaping William Bartee
# scaping Richard Bartel
# scaping Ron Bartell
# scaping Connor Barth
# scaping Brent Bartholomew
# scaping Sam Bartholomew
# scaping Steve Bartkowski
# scaping Doug Bartlett
# scaping Earl Bartlett
# scaping Rich Bartlewski
# scaping Ephesians Bartley
# scaping Don Barton
# scaping Eric Barton
# scaping Greg Barton
# scaping Harris Barton
# scaping Jim Barton
# scaping Karim Barton
# scaping Kirk Barton
# scaping Hank Bartos
# scaping Joe Bartos
# scaping Mike Bartrum
# scaping Joplo Bartu
# scaping Dick Barwegen
# scaping Connor Barwin
# scaping Carl Barzilauskas
# scaping Fritz Barzilauskas
# scaping Brett Basanez
# scaping Nick Basca
# scaping Brian Baschnagel
# scaping Tarell Basham
# scaping Mose Bashaw
# scaping Idrees Bashir
# scaping Myrt Basing
# scaping Michael Basinger
# scaping Rich Baska
# scaping Hank Baskett
# scaping Michael Basnight
# scaping Mike Basrak
# scaping Anthony Bass
# scaping Ben Bass
# scaping Bill Bass
# scaping David Bass
# scaping Dick Bass
# scaping Don Bass
# scaping Glenn Bass
# scaping Mike Bass
# scaping Norm Bass
# scaping Robert Bass
# scaping Henry Bassett
# scaping Maurice Bassett
# scaping Eric Bassey
# scaping Dick Bassi
# scaping Reds Bassman
# scaping Bert Baston
# scaping Baron Batch
# scaping Charlie Batch
# scaping Don Batchelor
# scaping Marv Bateman
# scaping Bill Bates
# scaping D'Wayne Bates
# scaping Daren Bates
# scaping Houston Bates
# scaping Jackie Bates
# scaping Jessie Bates III
# scaping Mario Bates
# scaping Michael Bates
# scaping Patrick Bates
# scaping Phil Bates
# scaping Solomon Bates
# scaping Ted Bates
# scaping Trevor Bates
# scaping Stan Batinski
# scaping D'Anthony Batiste
# scaping Michael Batiste
# scaping John Batorski
# scaping Cameron Batson
# scaping Marco Battaglia
# scaping Matt Battaglia
# scaping Pat Batteaux
# scaping Danny Batten
# scaping Pat Batten
# scaping Arnaz Battle
# scaping Jackie Battle
# scaping Jim Battle
# scaping Jim Battle
# scaping Julian Battle
# scaping Mike Battle
# scaping Ralph Battle
# scaping Ron Battle
# scaping Tra Battle
# scaping Ainsley Battles
# scaping Cliff Battles
# scaping Bobby Batton
# scaping Greg Baty
# scaping A.C. Bauer
# scaping Hank Bauer
# scaping Herb Bauer
# scaping John Bauer
# scaping Sammy Baugh
# scaping Tom Baugh
# scaping Maxie Baughan
# scaping Harry Baujan
# scaping Alf Bauman
# scaping Rashad Bauman
# scaping Zach Bauman
# scaping Buddy Baumann
# scaping Charlie Baumann
# scaping Joe Billy Baumgardner
# scaping Bill Baumgartner
# scaping Steve Baumgartner
# scaping Bob Baumhower
# scaping De'Vante Bausby
# scaping Frank Bausch
# scaping Jim Bausch
# scaping David Bavaro
# scaping Mark Bavaro
# scaping Bibbles Bawel
# scaping Carl Bax
# scaping Rob Baxley
# scaping Brad Baxter
# scaping Colin Baxter
# scaping Fred Baxter
# scaping Gary Baxter
# scaping Jarrod Baxter
# scaping Jimmy Baxter
# scaping Lloyd Baxter
# scaping Alex Bayer
# scaping Martin Bayless
# scaping Rick Bayless
# scaping Tom Bayless
# scaping John Bayley
# scaping Evan Baylis
# scaping John Baylor
# scaping Raymond Baylor
# scaping Tim Baylor
# scaping Chris Bayne
# scaping Craig Baynham
# scaping Reaves Baysinger
# scaping Winnie Baze
# scaping Fred Beach
# scaping Pat Beach
# scaping Sanjay Beach
# scaping Walter Beach
# scaping Kelvin Beachum
# scaping Zane Beadles
# scaping Jeremy Beal
# scaping Norm Beal
# scaping Bill Bealles
# scaping Alyn Beals
# scaping Shawn Beals
# scaping Tim Beamer
# scaping Autry Beamon
# scaping Willie Beamon
# scaping Byron Beams
# scaping Bubba Bean
# scaping Robert Bean
# scaping Ed Beard
# scaping Tom Beard
# scaping Aaron Beasley
# scaping Chad Beasley
# scaping Cole Beasley
# scaping Fred Beasley
# scaping John Beasley
# scaping John Beasley
# scaping Terry Beasley
# scaping Tom Beasley
# scaping Vic Beasley
# scaping Jon Beason
# scaping C.J. Beathard
# scaping Pete Beathard
# scaping Bob Beattie
# scaping Chuck Beatty
# scaping Ed Beatty
# scaping Will Beatty
# scaping Al Beauchamp
# scaping Joe Beauchamp
# scaping Doug Beaudoin
# scaping Clayton Beauford
# scaping Steve Beauharnais
# scaping Jim Beaver
# scaping Aubrey Beavers
# scaping Scott Beavers
# scaping Willie Beavers
# scaping Gary Beban
# scaping Nick Bebout
# scaping Brett Bech
# scaping Anthony Becht
# scaping Hub Bechtol
# scaping Braden Beck
# scaping Carl Beck
# scaping Clarence Beck
# scaping John Beck
# scaping Jordan Beck
# scaping Ken Beck
# scaping Marty Beck
# scaping Ray Beck
# scaping Dave Becker
# scaping Doug Becker
# scaping Johnnie Becker
# scaping Kurt Becker
# scaping Wayland Becker
# scaping Jack Beckett
# scaping Rogers Beckett
# scaping Odell Beckham Jr.
# scaping Tony Beckham
# scaping Ian Beckles
# scaping Art Beckley
# scaping Brad Beckman
# scaping Ed Beckman
# scaping Tom Beckman
# scaping Travis Beckum
# scaping Darry Beckwith
# scaping John Beckwith
# scaping Kendell Beckwith
# scaping Nick Becton
# scaping Brad Bedell
# scaping Gene Bedford
# scaping Vance Bedford
# scaping Chuck Bednarik
# scaping Al Bedner
# scaping Tom Bedore
# scaping Hal Bedsole
# scaping Chad Beebe
# scaping Don Beebe
# scaping Keith Beebe
# scaping Earl Beecham
# scaping Willie Beecher
# scaping Frank Beede
# scaping Bruce Beekley
# scaping Ferris Beekley
# scaping Josh Beekman
# scaping Bob Beemer
# scaping Tom Beer
# scaping Tom Beer
# scaping Terry Beeson
# scaping Charlie Behan
# scaping Bull Behman
# scaping Mark Behning
# scaping Dave Behrman
# scaping Tom Beier
# scaping Larry Beil
# scaping Ed Beinor
# scaping Jim Beirne
# scaping Monty Beisel
# scaping Randy Beisler
# scaping Bill Belanich
# scaping Jovan Belcher
# scaping Kevin Belcher
# scaping Kevin Belcher
# scaping Bunny Belden
# scaping Les Belding
# scaping Steve Belichick
# scaping Chuck Belin
# scaping Bill Belk
# scaping Rocky Belk
# scaping Veno Belk
# scaping Albert Bell
# scaping Anthony Bell
# scaping Beau Bell
# scaping Bill Bell
# scaping Billy Bell
# scaping Blake Bell
# scaping Bob Bell
# scaping Bobby Bell
# scaping Bobby Bell
# scaping Brandon Bell
# scaping Byron Bell
# scaping Carlos Bell
# scaping Coleman Bell
# scaping Demetress Bell
# scaping Ed Bell
# scaping Eddie Bell
# scaping Eddie Bell
# scaping Gordon Bell
# scaping Greg Bell
# scaping Henry Bell
# scaping Jacob Bell
# scaping Jason Bell
# scaping Jerry Bell
# scaping Joe Bell
# scaping Joique Bell
# scaping Josh Bell
# scaping Kahlil Bell
# scaping Kay Bell
# scaping Ken Bell
# scaping Kendrell Bell
# scaping Kerwin Bell
# scaping Kevin Bell
# scaping Le'Veon Bell
# scaping Len Bell
# scaping Marcus Bell
# scaping Marcus Bell
# scaping Mark Bell
# scaping Mark Bell
# scaping Mike Bell
# scaping Mike Bell
# scaping Myron Bell
# scaping Nick Bell
# scaping Richard Bell
# scaping Rick Bell
# scaping Ricky Bell
# scaping Ricky Bell
# scaping Shonn Bell
# scaping Tatum Bell
# scaping Theo Bell
# scaping Todd Bell
# scaping Tyrone Bell
# scaping Vonn Bell
# scaping William Bell
# scaping Yeremiah Bell
# scaping Jay Bellamy
# scaping Josh Bellamy
# scaping Mike Bellamy
# scaping Ronald Bellamy
# scaping Vic Bellamy
# scaping Bob Bellinger
# scaping Rodney Bellinger
# scaping Mark Bellini
# scaping Joe Bellino
# scaping Greg Bellisari
# scaping B.J. Bello
# scaping Nick Bellore
# scaping George Belotti
# scaping Ceasar Belser
# scaping Jason Belser
# scaping Horace Belton
# scaping Willie Belton
# scaping Deion Belue
# scaping Brian Belway
# scaping Al Bemiller
# scaping Marcus Benard
# scaping Carey Bender
# scaping Jacob Bender
# scaping Wes Bender
# scaping Jesse Bendross
# scaping Daved Benefield
# scaping Caleb Benenoch
# scaping Lou Benfatti
# scaping Tim Benford
# scaping Brant Bengen
# scaping Rolf Benirschke
# scaping Dan Benish
# scaping Bill Benjamin
# scaping Guy Benjamin
# scaping Kelvin Benjamin
# scaping Ryan Benjamin
# scaping Ryan Benjamin
# scaping Tony Benjamin
# scaping Travis Benjamin
# scaping Heinie Benkert
# scaping Arrelious Benn
# scaping Fred Benners
# scaping Antoine Bennett
# scaping Barry Bennett
# scaping Ben Bennett
# scaping Brandon Bennett
# scaping Charles Bennett
# scaping Charles Bennett
# scaping Chuck Bennett
# scaping Cornelius Bennett
# scaping Darren Bennett
# scaping Donnell Bennett
# scaping Drew Bennett
# scaping Earl Bennett
# scaping Edgar Bennett
# scaping Fred Bennett
# scaping Jug Bennett
# scaping Lewis Bennett
# scaping Martellus Bennett
# scaping Michael Bennett
# scaping Michael Bennett
# scaping Michael Bennett
# scaping Monte Bennett
# scaping Phil Bennett
# scaping Roy Bennett
# scaping Sean Bennett
# scaping Sid Bennett
# scaping Tommy Bennett
# scaping Tony Bennett
# scaping Woody Bennett
# scaping Brad Benson
# scaping Cedric Benson
# scaping Charles Benson
# scaping Cliff Benson
# scaping Darren Benson
# scaping Duane Benson
# scaping George Benson
# scaping Harry Benson
# scaping Mitchell Benson
# scaping Thomas Benson
# scaping Troy Benson
# scaping Albert Bentley
# scaping Bill Bentley
# scaping Ja'Whaun Bentley
# scaping Kevin Bentley
# scaping LeCharles Bentley
# scaping Ray Bentley
# scaping Scott Bentley
# scaping Jim Benton
# scaping Chris Bentz
# scaping Roman Bentz
# scaping Al Bentzin
# scaping Bene Benwikere
# scaping George Benyola
# scaping Eddie Benz
# scaping Larry Benz
# scaping Jake Bequette
# scaping Bob Bercich
# scaping Pete Bercich
# scaping Paul Berezney
# scaping Pete Berezney
# scaping Adam Bergen
# scaping Joe Berger
# scaping Mitch Berger
# scaping Ron Berger
# scaping Gil Bergerson
# scaping Eric Bergeson
# scaping Bill Bergey
# scaping Bruce Bergey
# scaping Scott Bergold
# scaping Tony Bergstrom
# scaping Nat Berhe
# scaping Brock Berlin
# scaping Eddie Berlin
# scaping Mackenzy Bernadeau
# scaping Chuck Bernard
# scaping Dave Bernard
# scaping George Bernard
# scaping Giovani Bernard
# scaping Karl Bernard
# scaping Rocky Bernard
# scaping Walter Bernard
# scaping Frank Bernardi
# scaping Mil Berner
# scaping Ed Bernet
# scaping Lee Bernet
# scaping George Bernhardt
# scaping Roger Bernhardt
# scaping Ken Bernich
# scaping Dan Bernoske
# scaping Bobby Berns
# scaping Rick Berns
# scaping Joe Bernstein
# scaping Jordan Bernstine
# scaping Rod Bernstine
# scaping Joy Berquist
# scaping Tim Berra
# scaping Ed Berrang
# scaping Bill Berrehsem
# scaping Bernard Berrian
# scaping Aaron Berry
# scaping Bertrand Berry
# scaping Bob Berry
# scaping Charlie Berry
# scaping Connie Mack Berry
# scaping Damien Berry
# scaping Ed Berry
# scaping Eric Berry
# scaping Gary Berry
# scaping George Berry
# scaping Gil Berry
# scaping Howard Berry
# scaping Jordan Berry
# scaping Latin Berry
# scaping Louis Berry
# scaping Ray Berry
# scaping Raymond Berry
# scaping Reggie Berry
# scaping Rex Berry
# scaping Royce Berry
# scaping Wayne Berry
# scaping Marv Berschet
# scaping Brenton Bersin
# scaping Libby Bertagnolli
# scaping Angelo Bertelli
# scaping Jim Bertelsen
# scaping Bill Berthusen
# scaping Tony Berti
# scaping Jim Bertoglio
# scaping Sean Berton
# scaping Tony Bertuca
# scaping Ed Berwick
# scaping Will Berzinski
# scaping Warren Beson
# scaping Davone Bess
# scaping Gerald Bess
# scaping Rufus Bess
# scaping Don Bessillieu
# scaping Art Best
# scaping Greg Best
# scaping Jahvid Best
# scaping Keith Best
# scaping Teddy Besta
# scaping Antoine Bethea
# scaping Elvin Bethea
# scaping Larry Bethea
# scaping Justin Bethel
# scaping McLeod Bethel-Thompson
# scaping Bobby Bethune
# scaping George Bethune
# scaping Larry Bettencourt
# scaping Doug Betters
# scaping James Betterson
# scaping Mike Bettiga
# scaping Jerome Bettis
# scaping Tom Bettis
# scaping Ed Bettridge
# scaping John Bettridge
# scaping Ladell Betts
# scaping Steve Beuerlein
# scaping Tom Beutler
# scaping David Beverly
# scaping Dwight Beverly
# scaping Ed Beverly
# scaping Eric Beverly
# scaping Randy Beverly
# scaping Brennen Beyer
# scaping George Beyers
# scaping Tim Biakabutuka
# scaping Frank Bianchini
# scaping Johnny Biancone
# scaping Dean Biasucci
# scaping E.J. Bibbs
# scaping Kapri Bibbs
# scaping Martin Bibla
# scaping Erik Bickerstaff
# scaping Duane Bickett
# scaping Taye Biddle
# scaping Josh Bidwell
# scaping Adolph Bieberstein
# scaping Leo Biedermann
# scaping Vince Biegel
# scaping Greg Biekert
# scaping Dick Bielski
# scaping Tom Bienemann
# scaping Troy Bienemann
# scaping Eric Bieniemy
# scaping Scotty Bierce
# scaping Kroy Biermann
# scaping Keishawn Bierria
# scaping Terreal Bierria
# scaping Lyle Bigbee
# scaping Atari Bigby
# scaping Keiron Bigby
# scaping E.J. Biggers
# scaping Riley Biggs
# scaping Verlon Biggs
# scaping Jack Bighead
# scaping Adam Bighill
# scaping Jonathan Bilbo
# scaping Dick Bilda
# scaping Fred Biletnikoff
# scaping Andrew Billings
# scaping Jace Billingsley
# scaping Ron Billingsley
# scaping John Billman
# scaping Frank Billock
# scaping Lewis Billups
# scaping Terry Billups
# scaping Christo Bilukidi
# scaping Brandon Bing
# scaping Darnell Bing
# scaping Les Bingaman
# scaping Craig Bingham
# scaping Don Bingham
# scaping Dwight Bingham
# scaping Gregg Bingham
# scaping Guy Bingham
# scaping Ryon Bingham
# scaping David Binn
# scaping Armon Binns
# scaping John Binotto
# scaping Dennis Biodrowski
# scaping John Biolo
# scaping Bront Bird
# scaping Cory Bird
# scaping Rodger Bird
# scaping Steve Bird
# scaping J.J. Birden
# scaping Carl Birdsong
# scaping Craig Birdsong
# scaping Dan Birdwell
# scaping Matt Birk
# scaping Keith Birlem
# scaping Tom Birney
# scaping Rob Bironas
# scaping Joe Biscaha
# scaping Bill Bishop
# scaping Blaine Bishop
# scaping Brandan Bishop
# scaping Desmond Bishop
# scaping Don Bishop
# scaping Freddie Bishop
# scaping Greg Bishop
# scaping Harold Bishop
# scaping Keith Bishop
# scaping Ken Bishop
# scaping Michael Bishop
# scaping Richard Bishop
# scaping Sonny Bishop
# scaping Adam Bisnowaty
# scaping Frank Bissell
# scaping Joel Bitonio
# scaping Don Bitterlich
# scaping Charlie Bivins
# scaping Herb Bizer
# scaping Del Bjork
# scaping Bob Bjorklund
# scaping Hank Bjorklund
# scaping Eric Bjornson
# scaping Ahmad Black
# scaping Avion Black
# scaping Barry Black
# scaping Blondy Black
# scaping Charlie Black
# scaping Conroy Black
# scaping James Black
# scaping James Black
# scaping Jordan Black
# scaping Mel Black
# scaping Mike Black
# scaping Mike Black
# scaping Nathan Black
# scaping Quincy Black
# scaping Stan Black
# scaping Tim Black
# scaping Todd Black
# scaping Peter Blackbear
# scaping Bill Blackburn
# scaping Chase Blackburn
# scaping Todd Blackledge
# scaping Hugh Blacklock
# scaping Ken Blackman
# scaping Stub Blackman
# scaping Don Blackmon
# scaping Harold Blackmon
# scaping Justin Blackmon
# scaping Robert Blackmon
# scaping Roosevelt Blackmon
# scaping Will Blackmon
# scaping Richard Blackmore
# scaping Saeed Blacknall
# scaping Jeff Blackshear
# scaping Angelo Blackson
# scaping Darryl Blackstock
# scaping Alois Blackwell
# scaping Hal Blackwell
# scaping Kelly Blackwell
# scaping Kory Blackwell
# scaping Will Blackwell
# scaping Glenn Blackwood
# scaping Lyle Blackwood
# scaping Willie Blade
# scaping Bennie Blades
# scaping Brian Blades
# scaping H.B. Blades
# scaping Brian Blados
# scaping Joe Blahak
# scaping Russ Blailock
# scaping Ed Blaine
# scaping George Blair
# scaping Matt Blair
# scaping Michael Blair
# scaping Paul Blair
# scaping Ronald Blair
# scaping Stanley Blair
# scaping T.C. Blair
# scaping Kerlin Blaise
# scaping Antwon Blake
# scaping Emory Blake
# scaping Jeff Blake
# scaping Philip Blake
# scaping Ricky Blake
# scaping Tom Blake
# scaping Dwayne Blakley
# scaping Robert Blakley
# scaping Justin Blalock
# scaping Cary Blanchard
# scaping Dick Blanchard
# scaping Matt Blanchard
# scaping Tom Blanchard
# scaping Rob Blanchflower
# scaping Carl Bland
# scaping Tony Bland
# scaping George Blanda
# scaping Ernie Blandin
# scaping Brian Blankenship
# scaping Greg Blankenship
# scaping Sid Blanks
# scaping Jerry Blanton
# scaping Robert Blanton
# scaping Scott Blanton
# scaping Anthony Blaylock
# scaping Derrick Blaylock
# scaping Phil Blazer
# scaping Tony Blazine
# scaping Jeff Bleamer
# scaping Curtis Bledsoe
# scaping Drew Bledsoe
# scaping Mal Bleecker
# scaping Mel Bleeker
# scaping Tom Bleick
# scaping Bob Bleier
# scaping Johnny Bleier
# scaping Rocky Bleier
# scaping Paul Blessing
# scaping Darrius Blevins
# scaping Tony Blevins
# scaping Dennis Bligen
# scaping Stan Blinka
# scaping Harry Bliss
# scaping Homer Bliss
# scaping Greg Bloedorn
# scaping Tom Blondin
# scaping Johnny Blood
# scaping Al Bloodgood
# scaping Alvin Blount
# scaping Ed Blount
# scaping Eric Blount
# scaping Jeb Blount
# scaping Lamar Blount
# scaping LeGarrette Blount
# scaping Mel Blount
# scaping Tony Blount
# scaping Al Blozis
# scaping Alfred Blue
# scaping Forrest Blue
# scaping Greg Blue
# scaping Luther Blue
# scaping Tony Blue
# scaping Jim Blumenstock
# scaping Herb Blumer
# scaping Matt Blundin
# scaping Dre' Bly
# scaping Ronnie Blye
# scaping Austin Blythe
# scaping Steve Boadway
# scaping Chris Board
# scaping Dwaine Board
# scaping Mack Boatner
# scaping Kenneth Boatright
# scaping Harry Boatswain
# scaping Bon Boatwright
# scaping Adam Bob
# scaping E. Bobadash
# scaping Chris Bober
# scaping Hubert Bobo
# scaping Orlando Bobo
# scaping Joe Bock
# scaping John Bock
# scaping Wayne Bock
# scaping Colby Bockwoldt
# scaping Leigh Bodden
# scaping Tony Boddie
# scaping Briean Boddy-Calhoun
# scaping Lynn Boden
# scaping Maury Bodenger
# scaping Ping Bodie
# scaping Shaun Bodiford
# scaping Russell Bodine
# scaping Patrick Body
# scaping Bill Boedeker
# scaping Evan Boehm
# scaping Jim Boeke
# scaping Fred Boensch
# scaping Marc Boerigter
# scaping Chuck Boerio
# scaping Champ Boettcher
# scaping Ike Boettger
# scaping Conor Boffeli
# scaping Rex Boggan
# scaping Mark Boggs
# scaping Taylor Boggs
# scaping Phil Bogle
# scaping George Bogue
# scaping Fred Bohannon
# scaping Tommy Bohanon
# scaping Dewey Bohling
# scaping Rob Bohlinger
# scaping Frank Bohlmann
# scaping Ron Bohm
# scaping Reed Bohovich
# scaping Karl Bohren
# scaping Rocky Boiman
# scaping Corey Bojorquez
# scaping Novo Bojovic
# scaping Kim Bokamper
# scaping George Bolan
# scaping Ned Bolcar
# scaping Brandon Bolden
# scaping Gary Bolden
# scaping Juran Bolden
# scaping Leroy Bolden
# scaping Omar Bolden
# scaping Rickey Bolden
# scaping Victor Bolden
# scaping Anquan Boldin
# scaping Chase Boldt
# scaping Brock Bolen
# scaping Michael Boley
# scaping Bookie Bolin
# scaping Clint Boling
# scaping Russ Bolinger
# scaping Nick Bolkovac
# scaping Don Boll
# scaping Kyle Boller
# scaping Garett Bolles
# scaping Brian Bollinger
# scaping Brooks Bollinger
# scaping Eddie Bollinger
# scaping Ted Bolser
# scaping Conrad Bolston
# scaping Andy Bolton
# scaping Harry Bolton
# scaping Ron Bolton
# scaping Scott Bolton
# scaping Lynn Bomar
# scaping Jack Bonadies
# scaping Chuck Bond
# scaping Devante Bond
# scaping Deyshawn Bond
# scaping Jim Bond
# scaping Rink Bond
# scaping Travis Bond
# scaping Bourbon Bondurant
# scaping Warren Bone
# scaping Ernie Bonelli
# scaping Shane Bonham
# scaping Chris Boniol
# scaping Alan Bonner
# scaping Brian Bonner
# scaping Glen Bonner
# scaping Melvin Bonner
# scaping Rik Bonness
# scaping Steve Bono
# scaping Elliott Bonowitz
# scaping Devontae Booker
# scaping Fred Booker
# scaping Lorenzo Booker
# scaping Marty Booker
# scaping Michael Booker
# scaping Vaughn Booker
# scaping Johnny Bookman
# scaping Billy Bookout
# scaping Bob Books
# scaping Alex Boone
# scaping Alfonso Boone
# scaping Dave Boone
# scaping Greg Boone
# scaping J.R. Boone
# scaping Jack Boone
# scaping Kadron Boone
# scaping Mike Boone
# scaping Dorian Boose
# scaping Clarence Booth
# scaping Cody Booth
# scaping Dick Booth
# scaping Issac Booth
# scaping Kevin Boothe
# scaping John Booty
# scaping Emerson Boozer
# scaping Fred Borak
# scaping Jon Borchardt
# scaping Dennis Borcky
# scaping Chris Bordano
# scaping Ben Bordelon
# scaping Ken Bordelon
# scaping Les Borden
# scaping Nate Borden
# scaping Breon Borders
# scaping Nate Borders
# scaping Diondre Borel
# scaping Nick Borelli
# scaping Justin Boren
# scaping Jocelyn Borgella
# scaping Dirk Borgognone
# scaping Chris Borland
# scaping Kyle Borland
# scaping Rich Borresen
# scaping Blake Bortles
# scaping John Borton
# scaping Mark Bortz
# scaping Jarvis Borum
# scaping Mike Boryla
# scaping Joey Bosa
# scaping John Bosa
# scaping Wade Bosarge
# scaping Frank Bosch
# scaping Ryan Boschetti
# scaping John Bosdett
# scaping Tony Boselli
# scaping Matthew Bosher
# scaping Bruce Bosley
# scaping Keith Bosley
# scaping Cap Boso
# scaping Kevin Boss
# scaping Don Bosseler
# scaping James Bostic
# scaping Jason Bostic
# scaping Jeff Bostic
# scaping Joe Bostic
# scaping John Bostic
# scaping Jonathan Bostic
# scaping Keith Bostic
# scaping Brandon Bostick
# scaping Lew Bostick
# scaping David Boston
# scaping McKinley Boston
# scaping Tre Boston
# scaping Ben Boswell
# scaping Chris Boswell
# scaping Brian Bosworth
# scaping Kyle Bosworth
# scaping Ron Botchan
# scaping Kirk Botkin
# scaping Scott Boucher
# scaping Jim Boudreaux
# scaping Lee Bouggess
# scaping Kevin Bouie
# scaping Tony Bouie
# scaping Gil Bouley
# scaping Michael Boulware
# scaping Peter Boulware
# scaping Todd Bouman
# scaping Emil Boures
# scaping Kendrick Bourne
# scaping Marc Boutte
# scaping Leon Boutwell
# scaping Tommy Boutwell
# scaping Shawn Bouwens
# scaping A.J. Bouye
# scaping Willie Bouyer
# scaping Matt Bouza
# scaping Tony Bova
# scaping Peter Bove
# scaping Luke Bowanko
# scaping Gordon Bowdell
# scaping Joe Bowden
# scaping Jim Bowdoin
# scaping Dwayne Bowe
# scaping Alvin Bowen
# scaping Ken Bowen
# scaping Matt Bowen
# scaping Stephen Bowen
# scaping David Bowens
# scaping Tim Bowens
# scaping Phil Bower
# scaping Tashawn Bower
# scaping Andy Bowers
# scaping Bill Bowers
# scaping Da'Quan Bowers
# scaping R.J. Bowers
# scaping Sam Bowers
# scaping Tony Bowick
# scaping John Bowie
# scaping Larry Bowie
# scaping Larry Bowie
# scaping Michael Bowie
# scaping Todd Bowles
# scaping Andy Bowling
# scaping Barry Bowman
# scaping Bill Bowman
# scaping Braedon Bowman
# scaping Jim Bowman
# scaping Ken Bowman
# scaping Kevin Bowman
# scaping NaVorro Bowman
# scaping Steve Bowman
# scaping Zackary Bowman
# scaping Fabien Bownes
# scaping Arda Bowser
# scaping Charles Bowser
# scaping Tyus Bowser
# scaping Walt Bowyer
# scaping Cloyce Box
# scaping Jerry Boyarsky
# scaping Dorson Boyce
# scaping Josh Boyce
# scaping Bill Boyd
# scaping Bob Boyd
# scaping Bobby Boyd
# scaping Brent Boyd
# scaping Chris Boyd
# scaping Cory Boyd
# scaping Danny Boyd
# scaping Dennis Boyd
# scaping Elmo Boyd
# scaping Greg Boyd
# scaping Greg Boyd
# scaping James Boyd
# scaping Jerome Boyd
# scaping Jerome Boyd
# scaping Josh Boyd
# scaping LaVell Boyd
# scaping Malik Boyd
# scaping Sam Boyd
# scaping Sean Boyd
# scaping Stephen Boyd
# scaping Thomas Boyd
# scaping Tommie Boyd
# scaping Tyler Boyd
# scaping Mike Boyda
# scaping Max Boydston
# scaping Brant Boyer
# scaping Mark Boyer
# scaping Verdi Boyer
# scaping John Boyett
# scaping Lon Boyett
# scaping Garland Boyette
# scaping Brandon Boykin
# scaping Deral Boykin
# scaping Greg Boykin
# scaping Jarrett Boykin
# scaping McKinley Boykin
# scaping Trevone Boykin
# scaping Brett Boyko
# scaping Jim Boylan
# scaping Jim Boyle
# scaping Knuckles Boyle
# scaping Nick Boyle
# scaping Benny Boynton
# scaping George Boynton
# scaping John Boynton
# scaping Bradley Bozeman
# scaping Ordell Braase
# scaping Tom Braatz
# ...
# scaping Gary Burley
# scaping Marcus Burley
# scaping George Burman
# scaping Danny Burmeister
# scaping Forrest Burmeister
# scaping Max Burnell
# scaping Bobby Burnett
# scaping Chester Burnett
# scaping Dale Burnett
# scaping Deontay Burnett
# scaping Joe Burnett
# scaping Kaelin Burnett
# scaping Kevin Burnett
# scaping Len Burnett
# scaping Morgan Burnett
# scaping Ray Burnett
# scaping Rob Burnett
# scaping Victor Burnett
# scaping Dave Burnette
# scaping Reggie Burnette
# scaping Tom Burnette
# scaping Kendric Burney
# scaping Lem Burnham
# scaping Stanley Burnham
# scaping Tim Burnham
# scaping Hank Burnine
# scaping Artie Burns
# scaping Curry Burns
# scaping Ed Burns
# scaping Jason Burns
# scaping Joe Burns
# scaping Keith Burns
# scaping Lamont Burns
# scaping Leon Burns
# scaping Mike Burns
# scaping Robert Burns
# scaping George Burnside
# scaping Clinton Burrell
# scaping George Burrell
# scaping John Burrell
# scaping Ode Burrell
# scaping Troy Burrell
# scaping Plaxico Burress
# scaping Bo Burris
# scaping Buddy Burris
# scaping Henry Burris
# scaping Jeff Burris
# scaping Juston Burris
# scaping Miles Burris
# scaping John Burrough
# scaping Ken Burrough
# scaping Derrick Burroughs
# scaping Don Burroughs
# scaping Jim Burroughs
# scaping Sammie Burroughs
# scaping Curtis Burrow
# scaping Jim Burrow
# scaping Ken Burrow
# scaping Harry Burrus
# scaping Lloyd Burruss
# scaping Isaiah Burse
# scaping Tony Burse
# scaping Jimmy Burson
# scaping Hal Burt
# scaping Jim Burt
# scaping Russ Burt
# scaping Al Burton
# scaping Antwon Burton
# scaping Brandon Burton
# scaping Deante Burton
# scaping Derek Burton
# scaping James Burton
# scaping Keenan Burton
# scaping Kendrick Burton
# scaping Larry Burton
# scaping Leon Burton
# scaping Leonard Burton
# scaping Lyle Burton
# scaping Michael Burton
# scaping Ron Burton
# scaping Ron Burton
# scaping Shane Burton
# scaping Stephen Burton
# scaping Trey Burton
# scaping Tyreek Burwell
# scaping Sherrill Busby
# scaping Elmer Busch
# scaping Mike Busch
# scaping Blair Bush
# scaping Deon Bush
# scaping Devin Bush Sr.
# scaping Frank Bush
# scaping Jarrett Bush
# scaping Josh Bush
# scaping Lewis Bush
# scaping Michael Bush
# scaping Rafael Bush
# scaping Ray Bush
# scaping Reggie Bush
# scaping Steve Bush
# scaping Tom Bushby
# scaping Jermon Bushrod
# scaping Sam Busich
# scaping Steve Busick
# scaping John Busing
# scaping Ray Busler
# scaping Art Buss
# scaping Gerry Bussell
# scaping Barney Bussey
# scaping Dexter Bussey
# scaping Nate Bussey
# scaping Young Bussey
# scaping Paul Butcher
# scaping Wendell Butcher
# scaping Harrison Butker
# scaping Carl Butkus
# scaping Dick Butkus
# scaping Adam Butler
# scaping Bill Butler
# scaping Bill Butler
# scaping Bill Butler
# scaping Bob Butler
# scaping Bobby Butler
# scaping Brad Butler
# scaping Brice Butler
# scaping Cannonball Butler
# scaping Chuck Butler
# scaping Crezdon Butler
# scaping Darius Butler
# scaping Dave Butler
# scaping Deon Butler
# scaping Donald Butler
# scaping Drew Butler
# scaping Duane Butler
# scaping Frank Butler
# scaping Gary Butler
# scaping Hillary Butler
# scaping Jack Butler
# scaping James Butler
# scaping Jerametrius Butler
# scaping Jeremy Butler
# scaping Jerry Butler
# scaping Jerry Butler
# scaping John Butler
# scaping Johnny Butler
# scaping Keith Butler
# scaping Kelly Butler
# scaping Kevin Butler
# scaping LeRoy Butler
# scaping Malcolm Butler
# scaping Mario Butler
# scaping Mike Butler
# scaping Quincy Butler
# scaping Rashad Butler
# scaping Ray Butler
# scaping Robb Butler
# scaping Skip Butler
# scaping Sol Butler
# scaping Terry Butler
# scaping Vernon Butler
# scaping Victor Butler
# scaping Harry Butsko
# scaping Jake Butt
# scaping Greg Buttle
# scaping Eddie Butts
# scaping Marion Butts
# scaping Dave Butz
# scaping Rich Buzin
# scaping Bernard Buzyniski
# scaping Butler By'not'e
# scaping Kevin Byard
# scaping Keith Byars
# scaping Rick Byas
# scaping Jeff Byers
# scaping Ken Byers
# scaping Scott Byers
# scaping Nate Byham
# scaping Carter Bykowski
# scaping Frank Bykowski
# scaping Joseph Byler
# scaping Carrington Byndom
# scaping Earnest Byner
# scaping Josh Bynes
# scaping Kenny Bynum
# scaping Reggie Bynum
# scaping Boris Byrd
# scaping Butch Byrd
# scaping Damiere Byrd
# scaping Darryl Byrd
# scaping Dennis Byrd
# scaping Dennis Byrd
# scaping Dominique Byrd
# scaping Emanuel Byrd
# scaping Gill Byrd
# scaping Isaac Byrd
# scaping Israel Byrd
# scaping Jairus Byrd
# scaping LaRon Byrd
# scaping Mac Byrd
# scaping Richard Byrd
# scaping Sylvester Byrd
# scaping Shawn Byrdsong
# scaping Bill Byrne
# scaping Jake Byrne
# scaping Carl Byrum
# scaping Dion Byrum
# scaping Jason Cabinda
# scaping Brian Cabral
# scaping Larry Cabrelli
# scaping Augie Cabrinha
# scaping Ernie Caddel
# scaping Eddie Cade
# scaping Mossy Cade
# scaping Travaris Cadet
# scaping Dave Cadigan
# scaping Jim Cadile
# scaping Glenn Cadrez
# scaping John Cadwell
# scaping Ivan Caesar
# scaping George Cafego
# scaping Lee Roy Caffey
# scaping Chris Cagle
# scaping Jim Cagle
# scaping John Cagle
# scaping Bill Cahill
# scaping Dave Cahill
# scaping Denny Cahill
# scaping Ronnie Cahill
# scaping Tiny Cahoon
# scaping J.V. Cain
# scaping Jeremy Cain
# scaping Jim Cain
# scaping Joe Cain
# scaping Lynn Cain
# scaping Patrick Cain
# scaping Pete Calac
# scaping Jeremy Calahan
# scaping Ralph Calcagni
# scaping Alan Caldwell
# scaping Andre Caldwell
# scaping Antoine Caldwell
# scaping Bruce Caldwell
# scaping Bryan Caldwell
# scaping Darryl Caldwell
# scaping David Caldwell
# scaping David Caldwell
# scaping Knute Caldwell
# scaping Mike Caldwell
# scaping Mike Caldwell
# scaping Ravin Caldwell
# scaping Reche Caldwell
# scaping Scott Caldwell
# scaping Tony Caldwell
# scaping Trey Caldwell
# scaping Jamie Caleb
# scaping Brian Calhoun
# scaping Don Calhoun
# scaping Duke Calhoun
# scaping Eric Calhoun
# scaping Mike Calhoun
# scaping Rick Calhoun
# scaping Shilique Calhoun
# scaping Taveze Calhoun
# scaping Lonny Calicchio
# scaping Tyrone Calico
# scaping Dean Caliguire
# scaping Austin Calitro
# scaping Jack Call
# scaping Kevin Call
# scaping Bill Callahan
# scaping Bob Callahan
# scaping Bryce Callahan
# scaping Dan Callahan
# scaping Jim Callahan
# scaping Joe Callahan
# scaping Lee Calland
# scaping Antonio Callaway
# scaping Rob Callaway
# scaping Ken Callicutt
# scaping Len Calligaro
# scaping Bill Callihan
# scaping Chris Calloway
# scaping Ernie Calloway
# scaping Rocky Calmus
# scaping Tony Calvelli
# scaping Jorrick Calvin
# scaping Tom Calvin
# scaping Greg Camarillo
# scaping Rich Camarillo
# scaping Dennis Cambal
# scaping Glenn Cameron
# scaping Jack Cameron
# scaping John Cameron
# scaping Jordan Cameron
# scaping Paul Cameron
# scaping Ronnie Cameron
# scaping Jim Camp
# scaping Reggie Camp
# scaping Al Campana
# scaping Michael Campanaro
# scaping Joe Campanella
# scaping Arnold Campbell
# scaping Bill Campbell
# scaping Bob Campbell
# scaping Bruce Campbell
# scaping Calais Campbell
# scaping Caleb Campbell
# scaping Carter Campbell
# scaping D.J. Campbell
# scaping Dan Campbell
# scaping De'Vondre Campbell
# scaping Dick Campbell
# scaping Don Campbell
# scaping Earl Campbell
# scaping Gary Campbell
# scaping Glenn Campbell
# scaping Ibraheim Campbell
# scaping Jack Campbell
# scaping Jason Campbell
# scaping Jeff Campbell
# scaping Jesse Campbell
# scaping Jim Campbell
# scaping Joe Campbell
# scaping Joe Campbell
# scaping John Campbell
# scaping Jordan Campbell
# scaping Kelly Campbell
# scaping Ken Campbell
# scaping Khary Campbell
# scaping Lamar Campbell
# scaping Leon Campbell
# scaping Marion Campbell
# scaping Mark Campbell
# scaping Mark Campbell
# scaping Matt Campbell
# scaping Michael Campbell
# scaping Mike Campbell
# scaping Milt Campbell
# scaping Rich Campbell
# scaping Russ Campbell
# scaping Scott Campbell
# scaping Sonny Campbell
# scaping Stan Campbell
# scaping Tommie Campbell
# scaping Tommy Campbell
# scaping William Campbell
# scaping Woody Campbell
# scaping James Campen
# scaping Billy Campfield
# scaping Bob Campiglio
# scaping T.J. Campion
# scaping Nick Campofreda
# scaping Don Campora
# scaping Alan Campos
# scaping Larry Canada
# scaping Kameron Canaday
# scaping Tony Canadeo
# scaping Jim Canady
# scaping Maurice Canady
# scaping Justin Canale
# scaping Rocco Canale
# scaping Whit Canale
# scaping Phil Cancik
# scaping Trung Canidate
# scaping Sheldon Canley
# scaping A.J. Cann
# scaping John Cannady
# scaping Pat Cannamela
# scaping Al Cannava
# scaping Joe Cannavino
# scaping John Cannella
# scaping James Cannida
# scaping Anthony Cannon
# scaping Billy Cannon
# scaping Billy Cannon
# scaping John Cannon
# scaping Marcus Cannon
# scaping Mark Cannon
# scaping Trenton Cannon
# scaping Leo Cantor
# scaping Barry Cantrell
# scaping Rolando Cantu
# scaping Chris Canty
# scaping Chris Canty
# scaping Bill Capece
# scaping James Capers
# scaping Selvish Capers
# scaping Wayne Capers
# scaping Nordly Capi
# scaping Warren Capone
# scaping Dick Capp
# scaping Alex Cappa
# scaping Bob Cappadona
# scaping Gino Cappelletti
# scaping John Cappelletti
# scaping Bill Cappleman
# scaping Bill Capps
# scaping Carl Capria
# scaping Ralph Capron
# scaping Jim Capuzzi
# scaping Mac Cara
# scaping Roland Caranci
# scaping Glenn Carano
# scaping Al Carapella
# scaping Joe Caravello
# scaping Glenn Carberry
# scaping Harper Card
# scaping Carl Cardarelli
# scaping Tank Carder
# scaping Fred Cardinal
# scaping Joe Cardona
# scaping Joe Cardwell
# scaping John Cardwell
# scaping Lloyd Cardwell
# scaping Bob Carey
# scaping Brian Carey
# scaping Don Carey
# scaping Joe Carey
# scaping Ka'Deem Carey
# scaping Richard Carey
# scaping Vernon Carey
# scaping Steve Cargile
# scaping Gabe Carimi
# scaping Harland Carl
# scaping Cooper Carlisle
# scaping Cody Carlson
# scaping Daniel Carlson
# scaping Dean Carlson
# scaping Hal Carlson
# scaping Irv Carlson
# scaping Jeff Carlson
# scaping John Carlson
# scaping Mark Carlson
# scaping Oke Carlson
# scaping Roy Carlson
# scaping Wes Carlson
# scaping Zuck Carlson
# scaping Darryl Carlton
# scaping Wray Carlton
# scaping Charlie Carman
# scaping Ed Carman
# scaping Jon Carman
# scaping Al Carmichael
# scaping Harold Carmichael
# scaping Paul Carmichael
# scaping Roc Carmichael
# scaping Ray Carnelly
# scaping Art Carney
# scaping Chuck Carney
# scaping John Carney
# scaping Brett Carolan
# scaping Reggie Carolan
# scaping J.C. Caroline
# scaping Joe Carollo
# scaping Roger Caron
# scaping Don Carothers
# scaping Joe Carpe
# scaping Bobby Carpenter
# scaping Brian Carpenter
# scaping Dan Carpenter
# scaping Dwaine Carpenter
# scaping Jack Carpenter
# scaping James Carpenter
# scaping Keion Carpenter
# scaping Ken Carpenter
# scaping Lew Carpenter
# scaping Preston Carpenter
# scaping Rob Carpenter
# scaping Rob Carpenter
# scaping Ron Carpenter
# scaping Ron Carpenter
# scaping Ron Carpenter
# scaping Rudy Carpenter
# scaping Steve Carpenter
# scaping Austin Carr
# scaping Brandon Carr
# scaping Carl Carr
# scaping Charley Carr
# scaping Chetti Carr
# scaping Chris Carr
# scaping David Carr
# scaping Derek Carr
# scaping Deveron Carr
# scaping Earl Carr
# scaping Eddie Carr
# scaping Fred Carr
# scaping Gregg Carr
# scaping Harlan Carr
# scaping Henry Carr
# scaping Jimmy Carr
# scaping Levert Carr
# scaping Lydell Carr
# scaping Paul Carr
# scaping Reggie Carr
# scaping Roger Carr
# scaping Tom Carr
# scaping Tank Carradine
# scaping Josh Carraway
# scaping Alphonso Carreker
# scaping Vince Carreker
# scaping Duane Carrell
# scaping John Carrell
# scaping Ryan Carrethers
# scaping T.J. Carrie
# scaping Derek Carrier
# scaping Mark Carrier
# scaping Mark Carrier
# scaping Adam Carriker
# scaping Alex Carrington
# scaping Darren Carrington
# scaping Ed Carrington
# scaping Paul Carrington
# scaping Russ Carroccio
# scaping Ahmad Carroll
# scaping Bart Carroll
# scaping Bird Carroll
# scaping Gene Carroll
# scaping Herman Carroll
# scaping Jay Carroll
# scaping Jim Carroll
# scaping Joe Carroll
# scaping Leo Carroll
# scaping Nolan Carroll
# scaping Ronnie Carroll
# scaping Travis Carroll
# scaping Victor Carroll
# scaping Wesley Carroll
# scaping Leonte Carroo
# scaping Paul Ott Carruth
# scaping Rae Carruth
# scaping Carlos Carson
# scaping Chris Carson
# scaping Glenn Carson
# scaping Harry Carson
# scaping Howard Carson
# scaping John Carson
# scaping Kern Carson
# scaping Leonardo Carson
# scaping Malcolm Carson
# scaping Tra Carson
# scaping Jordan Carstens
# scaping Dwayne Carswell
# scaping Robert Carswell
# scaping Alex Carter
# scaping Alex Carter
# scaping Allen Carter
# scaping Andre Carter
# scaping Anthony Carter
# scaping Bernard Carter
# scaping Blanchard Carter
# scaping Brandon Carter
# scaping Bruce Carter
# scaping Carl Carter
# scaping Cethan Carter
# scaping Chris Carter
# scaping Chris Carter
# scaping Cris Carter
# scaping Dale Carter
# scaping Daryl Carter
# scaping David Carter
# scaping David Carter
# scaping DeAndre Carter
# scaping Delone Carter
# scaping Dexter Carter
# scaping Drew Carter
# scaping Dyshod Carter
# scaping Gerald Carter
# scaping Jamal Carter
# scaping Jason Carter
# scaping Jermaine Carter Jr.
# scaping Jerome Carter
# scaping Jim Carter
# scaping Jimmie Carter
# scaping Joe Carter
# scaping Joe Carter
# scaping Jon Carter
# scaping Jonathan Carter
# scaping Kent Carter
# scaping Kerry Carter
# scaping Kevin Carter
# scaping Ki-Jana Carter
# scaping Kyle Carter
# scaping Lorenzo Carter
# scaping Louis Carter
# scaping M.L. Carter
# scaping Marty Carter
# scaping Michael Carter
# scaping Mike Carter
# scaping Pat Carter
# scaping Perry Carter
# scaping Quincy Carter
# scaping Quinton Carter
# scaping Rodney Carter
# scaping Ross Carter
# scaping Rubin Carter
# scaping Russell Carter
# scaping Steve Carter
# scaping Tim Carter
# scaping Tim Carter
# scaping Todd Carter
# scaping Tom Carter
# scaping Tony Carter
# scaping Tony Carter
# scaping Tyrone Carter
# scaping Virgil Carter
# scaping Walter Carter
# scaping Willie Carter
# scaping Jason Carthen
# scaping Milt Carthens
# scaping Maurice Carthon
# scaping Ran Carthon
# scaping Charlie Carton
# scaping Rock Cartwright
# scaping Johndale Carty
# scaping Dale Carver
# scaping Mel Carver
# scaping Shante Carver
# scaping Larry Carwell
# scaping Ken Casanega
# scaping Tommy Casanova
# scaping Rick Casares
# scaping Chad Cascadden
# scaping Ernie Case
# scaping Frank Case
# scaping Pete Case
# scaping Scott Case
# scaping Stoney Case
# scaping Alvro Casey
# scaping Bernie Casey
# scaping Chance Casey
# scaping Eddie Casey
# scaping James Casey
# scaping Jurrell Casey
# scaping Pete Casey
# scaping Tim Casey
# scaping Tom Casey
# scaping Antoine Cash
# scaping Chris Cash
# scaping Jeremy Cash
# scaping John Cash
# scaping Keith Cash
# scaping Kerry Cash
# scaping Rick Cash
# scaping Jonathan Casillas
# scaping Tony Casillas
# scaping Ken Casner
# scaping Antoine Cason
# scaping Aveion Cason
# scaping Jim Cason
# scaping Wendell Cason
# scaping Cy Casper
# scaping Dave Casper
# scaping Craig Cassady
# scaping Howard Cassady
# scaping Frank Cassara
# scaping Matt Cassel
# scaping Tom Cassese
# scaping Dick Cassiano
# scaping  Cassidy
# scaping Ron Cassidy
# scaping Walt Cassidy
# scaping Mike Casteel
# scaping Rich Caster
# scaping Jesse Castete
# scaping Jim Castiglia
# scaping Jeremiah Castille
# scaping Simeon Castille
# scaping Tim Castille
# scaping Luis Castillo
# scaping Eric Castle
# scaping Toby Caston
# scaping Anthony Castonzo
# scaping Chris Castor
# scaping Tony Catalano
# scaping Tyler Catalina
# scaping Alcides Catanho
# scaping Mark Catano
# scaping Chandler Catanzaro
# scaping Mike Catapano
# scaping Toney Catchings
# scaping Greg Cater
# scaping Mike Caterbone
# scaping Thomas Caterbone
# scaping Royal Cathcart
# scaping Sam Cathcart
# scaping Tom Catlin
# scaping Daryl Cato
# scaping Sean Cattouse
# scaping Jehuu Caulcrick
# scaping Mike Caussin
# scaping Carmen Cavalli
# scaping Matt Cavanaugh
# scaping Braxston Cave
# scaping Ronnie Caveness
# scaping Jim Caver
# scaping Quinton Caver
# scaping Ben Cavil
# scaping Kwame Cavil
# scaping Grady Cavness
# scaping John Cavosie
# scaping Lowell Caylor
# scaping Les Caywood
# scaping Lloyd Cearing
# scaping Curtis Ceaser
# scaping Chuck Cecil
# scaping Jimmy Cefalo
# scaping Brent Celek
# scaping Garrett Celek
# scaping Bob Celeri
# scaping Oliver Celestin
# scaping Mario Celotto
# scaping Tony Cemore
# scaping John Cenci
# scaping Larry Centers
# scaping Frank Cephous
# scaping Gene Ceppetelli
# scaping Matt Cercone
# scaping Gordy Ceresino
# scaping Joe Cerne
# scaping Marq Cerqua
# scaping Jacques Cesaire
# scaping William Cesare
# scaping Sal Cesario
# scaping Jeff Chadwick
# scaping Pat Chaffey
# scaping Mike Chalenski
# scaping George Chalmers
# scaping Byron Chamberlain
# scaping Chris Chamberlain
# scaping Dan Chamberlain
# scaping Garth Chamberlain
# scaping Frank Chamberlin
# scaping Guy Chamberlin
# scaping Bill Chambers
# scaping Chris Chambers
# scaping Kirk Chambers
# scaping Rusty Chambers
# scaping Wally Chambers
# scaping Al Chamblee
# scaping Corey Chamblin
# scaping Ed Champagne
# scaping Jim Champion
# scaping Brelon Chancellor
# scaping Kam Chancellor
# scaping Robert Chancey
# scaping Al Chandler
# scaping Bob Chandler
# scaping Chris Chandler

# %% [markdown]
# ### Combine Files to Create Dataset

# %%
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Profile Data

# %%
profile_path=r'C:\Users\stang\Google Drive\Data_for_fun\Fantasy_Football\2019FF\profile_data'
read_files = glob.glob(profile_path + "/*.json")
with open("profile_data.json", "wb") as outfile:
    outfile.write('[{}]'.format(
        ','.join([open(f, "rb").read() for f in read_files])))

# %%
profile_data = pd.read_json(profile_data)

# %%
profile_data.to_csv(os.path.join(profile_path,r'Profile_data.csv'))

# %% [markdown]
# ##### Stats Data

# %%
stats_path=r'C:\Users\stang\Google Drive\Data_for_fun\Fantasy_Football\2019FF\stats_data'
read_files = glob.glob(stats_path + "/*.json")
with open("stats_data.json", "wb") as outfile:
    outfile.write('[{}]'.format(
        ','.join([open(f, "rb").read() for f in read_files])))

# %%
stats_data = pd.read_json(stats_data)

# %%
stats_data.to_csv(os.path.join(stats_path,r'Stats_data.csv'))

# %% [markdown]
# ##### Merge Files

# %%
# join stats and profile on player id
gamelogs = pd.merge(stats_data, profile_data, on='player_id', how='left')
# rename and remove duplicate columns

# %% [markdown]
# ##### Remove unneeded data for fantasy football (want RB, WR, TE, and QB)

# %%
# filter

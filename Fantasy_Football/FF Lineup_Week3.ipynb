# %%
import pandas as pd
import numpy as np

def load_data():
    data = pd.read_csv("FantasyPros_2018_Week_3_FLEX_Rankings.csv")
    data["Std Dev"].replace(0.0, None, inplace=True)
    data["Score"] = data["Avg"] * data["Avg"] * np.sqrt(data["Std Dev"])
    data.sort_values(by="Score", inplace=True)
    data["Pos_Name"] = data.Pos.str[:2]
    data.drop(["WSIS"], axis=1, inplace=True)
    
    return data[(data["Best"] <= 150) & (data["Team"] != "FA")]


def load_MSBA_team():
    MSBA_team = pd.read_csv("MSBA_team.csv")
    
    return MSBA_team

def load_family_team():
    family_team = pd.read_csv("family_team.csv")
    
    return family_team


def flex():
    data = load_data() 
    MSBA_team = load_MSBA_team()
    family_team = load_family_team()
    data_MSBA = data[data["Flex Position (RB/WR/TE)"].isin(MSBA_team["Player"])]
    data_family = data[data["Flex Position (RB/WR/TE)"].isin(family_team["Player"])]
    
    return data_MSBA  # switch based on which lineup I want to look at


def run_b():
    data = load_data()
    
    return data[data["Pos_Name"] == "RB"].head(30)


def wide_r():
    data = load_data()
    
    return data[data["Pos_Name"] == "WR"].head(30)


def tight_end():
    data = load_data()
    
    return data[data["Pos_Name"] == "TE"].head(20)


def qb_data():
    qb_data = pd.read_csv("FantasyPros_2018_Week_3_QB_Rankings.csv")
    qb_data["Std Dev"].replace(0.0, None, inplace=True)
    qb_data["Score"] = qb_data["Avg"] * qb_data["Avg"] * np.sqrt(qb_data["Std Dev"])
    qb_data.sort_values(by="Score", inplace=True)
    qb_data.drop(["WSIS"], axis=1, inplace=True)
    
    return qb_data[(qb_data["Team"] != "FA") & (qb_data["Best"] <= 30)].head(32)


def dst_data():
    dst_data = pd.read_csv("FantasyPros_2018_Week_3_DST_Rankings.csv")
    dst_data["Std Dev"].replace(0.0, None, inplace=True)
    dst_data["Score"] = dst_data["Avg"] * dst_data["Avg"] * np.sqrt(dst_data["Std Dev"])
    dst_data.sort_values(by="Score", inplace=True)
    dst_data.drop(["WSIS"], axis=1, inplace=True)
    
    return dst_data.head(20)
    

def k_data():
    k_data = pd.read_csv("FantasyPros_2018_Week_3_K_Rankings.csv")
    k_data["Std Dev"].replace(0.0, None, inplace=True)
    k_data["Score"] = k_data["Avg"] * k_data["Avg"] * np.sqrt(k_data["Std Dev"])
    k_data.sort_values(by="Score", inplace=True)
    k_data.drop(["WSIS"], axis=1, inplace=True)
    
    return k_data[k_data["Team"] != "FA"].head(20)

# %%
flex()
# Out:
#       Rank Flex Position (RB/WR/TE) Team   Pos      Opp  Best  Worst    Avg  \
# 16    17.0        Odell Beckham Jr.  NYG   WR6   at HOU  11.0   28.0   17.6
# 21    22.0      JuJu Smith-Schuster  PIT   WR9    at TB  11.0   37.0   24.3
# 27    28.0          Giovani Bernard  CIN  RB15   at CAR  10.0   88.0   26.9
# 29    30.0              T.Y. Hilton  IND  WR14   at PHI  18.0   77.0   32.4
# 60    61.0             Rex Burkhead   NE  RB29   at DET  37.0   98.0   60.9
# 59    60.0           Isaiah Crowell  NYJ  RB28   at CLE  36.0   97.0   60.9
# 70    71.0            Tyler Lockett  SEA  WR36  vs. DAL  53.0  106.0   70.5
# 71    72.0             Randall Cobb   GB  WR37   at WAS  54.0  104.0   72.3
# 75    76.0            George Kittle   SF   TE4    at KC  21.0  108.0   78.1
# 82    83.0            Derrick Henry  TEN  RB35   at JAC  37.0  101.0   82.0
# 130  131.0             Josh Doctson  WAS  WR65   vs. GB  70.0  175.0  131.6
#
#      Std Dev         Score Pos_Name
# 16       3.4    571.169218       WR
# 21       4.4   1238.622274       WR
# 27       9.9   2276.785712       RB
# 29       6.8   2737.439167       WR
# 60      12.7  13217.108213       RB
# 59      12.9  13320.773395       RB
# 70       7.5  13611.590207       WR
# 71       7.7  14505.141079       WR
# 75      12.4  21478.943240       TE
# 82      13.7  24887.884828       RB
# 130     14.7  66400.361829       WR

# %%
run_b()
# Out:
#     Rank Flex Position (RB/WR/TE)  Team   Pos      Opp  Best  Worst   Avg  \
# 0    1.0              Todd Gurley   LAR   RB1  vs. LAC   1.0    3.0   1.2
# 1    2.0             Alvin Kamara    NO   RB2   at ATL   1.0    6.0   1.9
# 2    3.0          Ezekiel Elliott   DAL   RB3   at SEA   2.0   13.0   3.8
# 5    6.0            Melvin Gordon   LAC   RB5   at LAR   3.0   19.0   6.7
# 3    4.0             James Conner   PIT   RB4    at TB   1.0   27.0   6.0
# 6    7.0           Saquon Barkley   NYG   RB6   at HOU   3.0   32.0   8.7
# 7    8.0              Kareem Hunt    KC   RB7   vs. SF   1.0   28.0   9.1
# 9   10.0      Christian McCaffrey   CAR   RB8  vs. CIN   3.0   30.0  11.0
# 13  14.0            Jordan Howard   CHI  RB10   at ARI   3.0   25.0  14.3
# 11  12.0            Tevin Coleman   ATL   RB9   vs. NO   4.0   85.0  13.0
# 15  16.0            David Johnson   ARI  RB11  vs. CHI   4.0   41.0  17.2
# 20  21.0             Kenyan Drake   MIA  RB12  vs. OAK   8.0   57.0  21.7
# 24  25.0             Lamar Miller   HOU  RB14  vs. NYG   7.0   46.0  24.9
# 27  28.0          Giovani Bernard   CIN  RB15   at CAR  10.0   88.0  26.9
# 23  24.0          Latavius Murray   MIN  RB13  vs. BUF   6.0   91.0  25.9
# 34  35.0        Leonard Fournette  JAC   RB19  vs. TEN   5.0  121.0  26.3
# 30  31.0              Carlos Hyde   CLE  RB16  vs. NYJ  20.0   87.0  35.5
# 31  32.0              Matt Breida    SF  RB17    at KC  17.0   84.0  35.9
# 38  39.0             Alex Collins   BAL  RB22  vs. DEN  23.0   81.0  38.1
# 37  38.0           Marshawn Lynch   OAK  RB21   at MIA  20.0   96.0  39.0
# 32  33.0           Chris Thompson   WAS  RB18   vs. GB  10.0  126.0  36.5
# 36  37.0            Corey Clement  PHI   RB20  vs. IND   7.0  108.0  38.0
# 49  50.0          Phillip Lindsay   DEN  RB25   at BAL  33.0   85.0  48.7
# 47  48.0               Dion Lewis   TEN  RB24   at JAC  23.0   99.0  48.6
# 44  45.0          Adrian Peterson   WAS  RB23   vs. GB  19.0  100.0  47.2
# 51  52.0            Peyton Barber    TB  RB26  vs. PIT  33.0  128.0  52.8
# 54  55.0          Jamaal Williams    GB  RB27   at WAS  31.0  106.0  56.6
# 60  61.0             Rex Burkhead    NE  RB29   at DET  37.0   98.0  60.9
# 59  60.0           Isaiah Crowell   NYJ  RB28   at CLE  36.0   97.0  60.9
# 66  67.0              James White    NE  RB31   at DET  43.0  106.0  65.3
#
#     Std Dev         Score Pos_Name
# 0       0.5      1.018234       RB
# 1       0.6      2.796294       RB
# 2       1.7     18.827457       RB
# 5       3.0     77.751761       RB
# 3       4.7     78.046140       RB
# 6       4.4    158.768683       RB
# 7       5.3    190.642937       RB
# 9       4.4    253.811741       RB
# 13      4.7    443.323756       RB
# 11      9.1    509.808886       RB
# 15      8.2    847.156837       RB
# 20      6.5   1200.538649       RB
# 24      6.4   1568.515018       RB
# 27      9.9   2276.785712       RB
# 23     16.8   2749.502817       RB
# 34     16.4   2801.131007       RB
# 30      8.9   3759.687162       RB
# 31      9.9   4055.145995       RB
# 38     10.1   4613.288749       RB
# 37      9.6   4712.646136       RB
# 32     13.6   4913.095241       RB
# 36     17.8   6092.242674       RB
# 49      9.2   7193.691945       RB
# 47      9.8   7394.104368       RB
# 44     13.3   8124.746468       RB
# 51     15.0  10797.257892       RB
# 54     14.1  12029.357136       RB
# 60     12.7  13217.108213       RB
# 59     12.9  13320.773395       RB
# 66     12.6  15136.017985       RB

# %%
tight_end()
# Out:
#       Rank Flex Position (RB/WR/TE) Team   Pos      Opp  Best  Worst    Avg  \
# 17    18.0           Rob Gronkowski   NE   TE1   at DET  10.0   71.0   20.0
# 33    34.0             Travis Kelce   KC   TE2   vs. SF  15.0   90.0   37.8
# 40    41.0                Zach Ertz  PHI   TE3  vs. IND  15.0   74.0   41.0
# 76    77.0             Jimmy Graham   GB   TE5   at WAS  50.0  108.0   79.9
# 75    76.0            George Kittle   SF   TE4    at KC  21.0  108.0   78.1
# 78    79.0              Jordan Reed  WAS   TE6   vs. GB  46.0  120.0   81.6
# 91    92.0             Kyle Rudolph  MIN   TE7  vs. BUF  65.0  132.0   94.7
# 94    95.0              Evan Engram  NYG   TE8   at HOU  53.0  130.0   95.7
# 101  102.0               Jared Cook  OAK  TE10   at MIA  72.0  131.0  104.6
# 95    96.0               Eric Ebron  IND   TE9   at PHI  54.0  169.0   96.9
# 102  103.0              Trey Burton  CHI  TE11   at ARI  52.0  139.0  105.2
# 110  111.0              O.J. Howard   TB  TE12  vs. PIT  65.0  151.0  112.4
# 118  119.0              David Njoku  CLE  TE13  vs. NYJ  73.0  155.0  120.5
# 131  132.0  Austin Seferian-Jenkins  JAC  TE14  vs. TEN  74.0  169.0  133.4
# 138  139.0             Tyler Eifert  CIN  TE17   at CAR  89.0  178.0  136.4
# 135  136.0          Benjamin Watson   NO  TE15   at ATL  82.0  179.0  135.3
# 141  142.0            Austin Hooper  ATL  TE19   vs. NO  76.0  180.0  138.7
# 137  138.0              Will Dissly  SEA  TE16  vs. DAL  76.0  171.0  136.9
# 139  140.0              Jesse James  PIT  TE18    at TB  71.0  209.0  138.2
# 151  152.0        Ricky Seals-Jones  ARI  TE20  vs. CHI  83.0  193.0  147.3
#
#      Std Dev         Score Pos_Name
# 17       8.4   1159.310140       TE
# 33      10.3   4585.663810       TE
# 40       9.3   5126.361019       TE
# 76      11.1  21269.390655       TE
# 75      12.4  21478.943240       TE
# 78      12.1  23161.837091       TE
# 91      13.1  32459.035122       TE
# 94      13.4  33525.578051       TE
# 101     12.7  38991.076841       TE
# 95      18.6  40495.244569       TE
# 102     15.5  43570.980051       TE
# 110     14.8  48603.045149       TE
# 118     14.9  56048.917340       TE
# 131     11.8  61129.756072       TE
# 138     12.0  64449.471986       TE
# 135     12.4  64462.394817       TE
# 141     15.2  75002.323240       TE
# 137     18.7  81045.274870       TE
# 139     18.6  82370.662347       TE
# 151     15.0  84033.242828       TE

# %%
wide_r()
# Out:
#     Rank Flex Position (RB/WR/TE)  Team   Pos      Opp  Best  Worst   Avg  \
# 4    5.0            Antonio Brown   PIT   WR1    at TB   3.0   21.0   6.7
# 8    9.0           Michael Thomas    NO   WR2   at ATL   3.0   16.0   9.1
# 10  11.0              Julio Jones   ATL   WR3   vs. NO   5.0   26.0  12.9
# 12  13.0          DeAndre Hopkins   HOU   WR4  vs. NYG   5.0   25.0  14.2
# 14  15.0              Tyreek Hill    KC   WR5   vs. SF   9.0   26.0  16.6
# 16  17.0        Odell Beckham Jr.   NYG   WR6   at HOU  11.0   28.0  17.6
# 18  19.0               A.J. Green   CIN   WR7   at CAR   8.0   33.0  20.4
# 19  20.0               Mike Evans    TB   WR8  vs. PIT   7.0   29.0  20.9
# 21  22.0      JuJu Smith-Schuster   PIT   WR9    at TB  11.0   37.0  24.3
# 22  23.0             Stefon Diggs   MIN  WR10  vs. BUF  12.0   54.0  24.9
# 25  26.0            Davante Adams    GB  WR11   at WAS  14.0   69.0  27.2
# 26  27.0             Adam Thielen   MIN  WR12  vs. BUF  15.0   70.0  28.0
# 28  29.0             Keenan Allen   LAC  WR13   at LAR  17.0   72.0  30.7
# 29  30.0              T.Y. Hilton   IND  WR14   at PHI  18.0   77.0  32.4
# 39  40.0           Nelson Agholor   PHI  WR16  vs. IND  22.0   78.0  40.8
# 35  36.0            Brandin Cooks   LAR  WR15  vs. LAC  12.0   79.0  38.3
# 42  43.0            Jarvis Landry  CLE   WR18  vs. NYJ  24.0   93.0  43.3
# 41  42.0              Golden Tate   DET  WR17   vs. NE  20.0   85.0  43.1
# 43  44.0         Emmanuel Sanders   DEN  WR19   at BAL  26.0   80.0  44.0
# 46  47.0           Kenny Golladay   DET  WR21   vs. NE  27.0   84.0  49.4
# 45  46.0           Allen Robinson   CHI  WR20   at ARI  28.0   86.0  48.4
# 48  49.0             Amari Cooper   OAK  WR22   at MIA  30.0   91.0  49.9
# 50  51.0              Chris Hogan    NE  WR23   at DET  22.0  108.0  51.6
# 53  54.0             Marvin Jones  DET   WR25   vs. NE  30.0   94.0  57.9
# 58  59.0         Demaryius Thomas   DEN  WR29   at BAL  46.0   79.0  61.7
# 52  53.0              Will Fuller   HOU  WR24  vs. NYG  35.0  107.0  57.5
# 55  56.0         Larry Fitzgerald  ARI   WR26  vs. CHI  30.0  116.0  59.9
# 61  62.0            Sammy Watkins    KC  WR30   vs. SF  41.0  106.0  64.2
# 57  58.0              Keelan Cole   JAC  WR28  vs. TEN  33.0  101.0  62.0
# 62  63.0             Kenny Stills   MIA  WR31  vs. OAK  40.0  102.0  64.2
#
#     Std Dev         Score Pos_Name
# 4       3.3     81.546735       WR
# 8       3.0    143.431127       WR
# 10      3.2    297.683258       WR
# 12      2.9    343.380547       WR
# 14      3.6    522.838339       WR
# 16      3.4    571.169218       WR
# 18      4.3    862.967743       WR
# 19      4.0    873.620000       WR
# 21      4.4   1238.622274       WR
# 22      5.3   1427.370211       WR
# 25      5.7   1766.343790       WR
# 26      6.3   1967.824382       WR
# 28      6.2   2346.781174       WR
# 29      6.8   2737.439167       WR
# 39      6.5   4244.015922       WR
# 35      9.8   4592.092058       WR
# 42      7.8   5236.282803       WR
# 41      8.1   5286.850744       WR
# 43      7.6   5337.183677       WR
# 46      7.1   6502.540596       WR
# 45      8.4   6789.383902       WR
# 48      9.2   7552.574274       WR
# 50     12.7   9488.580878       WR
# 53      9.0  10057.230000       WR
# 58      7.9  10700.002366       WR
# 52     10.8  10865.446235       WR
# 55      9.3  10941.959905       WR
# 61      8.3  11874.329674       WR
# 57      9.6  11910.198386       WR
# 62      9.5  12703.747666       WR

# %%
qb_data()
# Out:
#     Rank        Quarterbacks Team      Opp  Best  Worst   Avg  Std Dev  \
# 0    1.0     Patrick Mahomes   KC   vs. SF   1.0    6.0   1.4      0.9
# 1    2.0           Tom Brady   NE   at DET   1.0    8.0   2.1      1.0
# 2    3.0          Drew Brees   NO   at ATL   1.0   12.0   5.3      2.3
# 3    4.0       Aaron Rodgers  GB    at WAS   2.0   14.0   5.4      2.3
# 4    5.0          Cam Newton  CAR  vs. CIN   2.0   12.0   5.8      2.7
# 5    6.0  Ben Roethlisberger  PIT    at TB   2.0   14.0   6.3      2.5
# 6    7.0        Kirk Cousins  MIN  vs. BUF   1.0   13.0   6.6      2.5
# 7    8.0      Deshaun Watson  HOU  vs. NYG   3.0   12.0   7.1      2.5
# 8    9.0    Ryan Fitzpatrick   TB  vs. PIT   2.0   16.0   8.2      2.7
# 9   10.0    Matthew Stafford  DET   vs. NE   4.0   14.0   9.6      2.0
# 10  11.0     Jimmy Garoppolo   SF    at KC   3.0   18.0  10.6      2.6
# 11  12.0           Matt Ryan  ATL   vs. NO   5.0   19.0  11.5      2.3
# 13  14.0      Russell Wilson  SEA  vs. DAL  10.0   22.0  14.1      2.5
# 12  13.0        Carson Wentz  PHI  vs. IND   6.0   22.0  13.9      2.8
# 14  15.0          Jared Goff  LAR  vs. LAC  10.0   23.0  15.8      2.3
# 15  16.0         Andrew Luck  IND   at PHI   9.0   28.0  16.5      2.2
# 16  17.0       Blake Bortles  JAC  vs. TEN  10.0   24.0  17.1      2.3
# 17  18.0          Alex Smith  WAS   vs. GB  11.0   21.0  17.2      2.3
# 19  20.0       Philip Rivers  LAC   at LAR  11.0   25.0  19.4      2.8
# 18  19.0        Tyrod Taylor  CLE  vs. NYJ  11.0   29.0  19.4      2.9
# 21  22.0      Ryan Tannehill  MIA  vs. OAK  13.0   26.0  20.9      2.4
# 20  21.0         Andy Dalton  CIN   at CAR  11.0   27.0  20.6      2.6
# 25  26.0        Dak Prescott  DAL   at SEA  20.0   30.0  24.7      1.8
# 22  23.0          Joe Flacco  BAL  vs. DEN  16.0   30.0  24.1      2.1
# 27  28.0      Mitch Trubisky  CHI   at ARI  21.0   29.0  24.6      2.1
# 31  32.0          Josh Allen  BUF   at MIN  29.0   33.0  31.5      0.8
# 23  24.0          Derek Carr  OAK   at MIA  20.0   31.0  25.1      2.0
# 30  31.0        Sam Bradford  ARI  vs. CHI  28.0   34.0  31.0      1.0
# 26  27.0         Sam Darnold  NYJ   at CLE  20.0   31.0  27.3      1.8
# 28  29.0         Case Keenum  DEN   at BAL  21.0   30.0  26.7      2.1
# 24  25.0         Eli Manning  NYG   at HOU  19.0   30.0  27.7      1.9
# 32  33.0      Blaine Gabbert  TEN   at JAC  30.0   34.0  32.1      1.3
#
#           Score
# 0      1.859419
# 1      4.410000
# 2     42.600594
# 3     44.223330
# 4     55.276161
# 5     62.755400
# 6     68.874407
# 7     79.705208
# 8    110.486594
# 9    130.333922
# 10   181.175056
# 11   200.567055
# 13   314.346211
# 12   323.302167
# 14   378.597805
# 15   403.812008
# 16   443.461722
# 17   448.663574
# 19   629.770735
# 18   640.917985
# 21   676.703142
# 20   684.259940
# 25   818.521627
# 22   841.673653
# 27   876.960155
# 31   887.495380
# 23   890.968686
# 30   961.000000
# 26   999.911462
# 28  1033.075757
# 24  1057.636277
# 32  1174.848160

# %%
dst_data()
# Out:
#     Rank            Team DST      Opp  Best  Worst   Avg  Std Dev       Score
# 0    1.0     Minnesota (MIN)  vs. BUF   1.0    9.0   1.3      1.0    1.690000
# 2    3.0  Jacksonville (JAC)  vs. TEN   1.0    5.0   2.8      0.8    7.012309
# 1    2.0       Chicago (CHI)   at ARI   1.0   27.0   2.5      2.5    9.882118
# 3    4.0     Baltimore (BAL)  vs. DEN   2.0   21.0   5.7      2.4   50.333292
# 5    6.0     Cleveland (CLE)  vs. NYJ   3.0   12.0   6.2      2.0   54.362369
# 4    5.0       Houston (HOU)  vs. NYG   2.0   24.0   5.7      2.8   54.366169
# 6    7.0  Philadelphia (PHI)  vs. IND   4.0   16.0   7.4      2.2   81.222206
# 7    8.0   Los Angeles (LAR)  vs. LAC   1.0   21.0   8.2      3.0  116.463096
# 9   10.0      Carolina (CAR)  vs. CIN   6.0   19.0  10.8      2.6  188.076349
# 8    9.0        Denver (DEN)   at BAL   3.0   24.0  10.3      4.0  212.180000
# 10  11.0        Dallas (DAL)   at SEA   3.0   25.0  11.0      3.3  219.807416
# 11  12.0         Miami (MIA)  vs. OAK   6.0   26.0  12.2      2.8  249.056957
# 12  13.0      New York (NYJ)   at CLE   5.0   19.0  13.0      2.7  277.695337
# 13  14.0    New England (NE)   at DET   7.0   24.0  14.3      2.8  342.177218
# 14  15.0    Cincinnati (CIN)   at CAR   7.0   23.0  15.0      2.6  362.801599
# 16  17.0      Green Bay (GB)   at WAS   8.0   23.0  16.6      2.4  426.895716
# 15  16.0       Seattle (SEA)  vs. DAL   7.0   28.0  15.9      3.2  452.240276
# 18  19.0      New York (NYG)   at HOU  12.0   29.0  18.5      2.6  551.861543
# 17  18.0       Arizona (ARI)  vs. CHI   7.0   32.0  18.2      3.9  654.146587
# 19  20.0     Tennessee (TEN)   at JAC  11.0   31.0  20.2      2.8  682.781514

# %%
k_data()
# Out:
#     Rank             Kickers Team      Opp  Best  Worst   Avg  Std Dev  \
# 0    1.0  Stephen Gostkowski   NE   at DET   1.0   16.0   1.7      1.8
# 1    2.0     Harrison Butker   KC   vs. SF   1.0   15.0   2.9      2.8
# 2    3.0       Justin Tucker  BAL  vs. DEN   1.0   23.0   3.8      3.0
# 3    4.0         Matt Bryant  ATL   vs. NO   1.0   17.0   4.9      2.5
# 4    5.0          Dan Bailey  MIN  vs. BUF   1.0   17.0   5.4      2.5
# 5    6.0            Wil Lutz   NO   at ATL   2.0   19.0   6.3      2.4
# 6    7.0        Jake Elliott  PHI  vs. IND   2.0   19.0   7.7      2.4
# 7    8.0       Chris Boswell  PIT    at TB   2.0   21.0   8.6      3.1
# 8    9.0        Robbie Gould   SF    at KC   1.0   21.0   9.0      3.1
# 9   10.0        Mason Crosby   GB   at WAS   2.0   25.0  10.8      3.5
# 11  12.0          Sam Ficken  LAR  vs. LAC   4.0   19.0  11.7      2.9
# 10  11.0         Matt Prater  DET   vs. NE   3.0   26.0  11.3      3.5
# 12  13.0         Graham Gano  CAR  vs. CIN   5.0   28.0  13.3      2.7
# 13  14.0          Josh Lambo  JAC  vs. TEN   2.0   28.0  13.5      3.5
# 14  15.0  Chandler Catanzaro   TB  vs. PIT   5.0   24.0  14.4      3.0
# 16  17.0    Ka'imi Fairbairn  HOU  vs. NYG   9.0   22.0  16.8      2.4
# 15  16.0      Adam Vinatieri  IND   at PHI   1.0   26.0  16.4      3.7
# 17  18.0         Cody Parkey  CHI   at ARI   8.0   27.0  17.8      3.0
# 18  19.0      Dustin Hopkins  WAS   vs. GB   7.0   32.0  19.1      3.0
# 19  20.0     Brandon McManus  DEN   at BAL   7.0   33.0  20.3      3.5
#
#          Score
# 0     3.877342
# 1    14.072622
# 2    25.010814
# 3    37.963143
# 4    46.106008
# 5    61.487484
# 6    91.851673
# 7   130.220018
# 8   142.615217
# 9   218.213459
# 11  233.115270
# 10  238.886116
# 12  290.659930
# 13  340.958529
# 14  359.158055
# 16  437.244328
# 15  517.354890
# 17  548.782978
# 18  631.869455
# 19  770.949796

# %%
import pandas as pd
import numpy as np

def load_data():
    data = pd.read_csv("FantasyPros_2018_Week_1_FLEX_Rankings.csv")
    data["Std Dev"].replace(0.0, None, inplace=True)
    data["Score"] = data["Avg"] * data["Avg"] * np.sqrt(data["Std Dev"])
    data.sort_values(by="Score", inplace=True)
    data["Pos_Name"] = data.Pos.str[:2]
    data.drop(["WSIS"], axis=1, inplace=True)
    
    return data[(data["Best"] <= 150) & (data["Team"] != "FA")]


def load_MSBA_team():
    MSBA_team = pd.read_csv("MSBA_team.csv")
    
    return MSBA_team

def load_family_team():
    family_team = pd.read_csv("family_team.csv")
    
    return family_team


def flex():
    data = load_data() 
    MSBA_team = load_MSBA_team()
    family_team = load_family_team()
    data_MSBA = data[data["Flex Position (RB/WR/TE)"].isin(MSBA_team["Player"])]
    data_family = data[data["Flex Position (RB/WR/TE)"].isin(family_team["Player"])]
    
    return data_family  # switch based on which lineup I want to look at


def run_b():
    data = load_data()
    
    return data[data["Pos_Name"] == "RB"].head(30)


def wide_r():
    data = load_data()
    
    return data[data["Pos_Name"] == "WR"].head(30)


def tight_end():
    data = load_data()
    
    return data[data["Pos_Name"] == "TE"].head(20)


def qb_data():
    qb_data = pd.read_csv("FantasyPros_2018_Week_1_QB_Rankings.csv")
    qb_data["Std Dev"].replace(0.0, None, inplace=True)
    qb_data["Score"] = qb_data["Avg"] * qb_data["Avg"] * np.sqrt(qb_data["Std Dev"])
    qb_data.sort_values(by="Score", inplace=True)
    qb_data.drop(["WSIS"], axis=1, inplace=True)
    
    return qb_data[(qb_data["Team"] != "FA") & (qb_data["Best"] <= 30)].head(32)


def dst_data():
    dst_data = pd.read_csv("FantasyPros_2018_Week_1_DST_Rankings.csv")
    dst_data["Std Dev"].replace(0.0, None, inplace=True)
    dst_data["Score"] = dst_data["Avg"] * dst_data["Avg"] * np.sqrt(dst_data["Std Dev"])
    dst_data.sort_values(by="Score", inplace=True)
    dst_data.drop(["WSIS"], axis=1, inplace=True)
    
    return dst_data.head(20)
    

def k_data():
    k_data = pd.read_csv("FantasyPros_2018_Week_1_K_Rankings.csv")
    k_data["Std Dev"].replace(0.0, None, inplace=True)
    k_data["Score"] = k_data["Avg"] * k_data["Avg"] * np.sqrt(k_data["Std Dev"])
    k_data.sort_values(by="Score", inplace=True)
    k_data.drop(["WSIS"], axis=1, inplace=True)
    
    return k_data[k_data["Team"] != "FA"].head(20)

# %%
flex()
# Out:
#      Rank Flex Position (RB/WR/TE) Team   Pos      Opp  Best  Worst    Avg  \
# 1     2.0            David Johnson  ARI   RB2  vs. WAS   1.0    5.0    2.5
# 19   20.0            Jordan Howard  CHI  RB13    at GB   9.0   43.0   20.4
# 24   25.0             LeSean McCoy  BUF  RB17   at BAL  12.0   80.0   27.2
# 34   35.0              Chris Hogan   NE  WR12  vs. HOU  16.0   49.0   34.6
# 27   28.0             James Conner  PIT  RB18   at CLE  11.0  127.0   28.4
# 48   49.0      JuJu Smith-Schuster  PIT  WR21   at CLE  32.0   93.0   49.0
# 58   59.0          Adrian Peterson  WAS  RB29   at ARI  35.0  113.0   62.5
# 74   75.0             Kyle Rudolph  MIN   TE7   vs. SF  44.0  123.0   78.3
# 93   94.0              Allen Hurns  DAL  WR45   at CAR  69.0  143.0   96.0
# 99  100.0            Mike Williams  LAC  WR48   vs. KC  47.0  159.0  101.6
#
#     Std Dev         Score Pos_Name
# 1       1.0      6.250000       RB
# 19      5.1    939.821601       RB
# 24     11.7   2530.642160       RB
# 34      6.8   3121.811341       WR
# 27     16.4   3266.319052       RB
# 48      9.6   7439.226411       WR
# 58     14.5  14874.556847       RB
# 74     12.0  21238.025951       TE
# 93     12.7  32843.113908       WR
# 99     20.6  46851.233133       WR

# %%
run_b()
# Out:
#     Rank Flex Position (RB/WR/TE) Team   Pos      Opp  Best  Worst   Avg  \
# 0    1.0              Todd Gurley  LAR   RB1   at OAK   1.0    4.0   1.2
# 1    2.0            David Johnson  ARI   RB2  vs. WAS   1.0    5.0   2.5
# 2    3.0             Alvin Kamara   NO   RB3   vs. TB   1.0   11.0   3.2
# 3    4.0            Melvin Gordon  LAC   RB4   vs. KC   2.0   16.0   5.4
# 4    5.0          Ezekiel Elliott  DAL   RB5   at CAR   3.0   19.0   5.6
# 5    6.0        Leonard Fournette  JAC   RB6   at NYG   3.0    9.0   6.5
# 6    7.0              Kareem Hunt   KC   RB7   at LAC   4.0   34.0   9.4
# 7    8.0      Christian McCaffrey  CAR   RB8  vs. DAL   5.0   24.0  10.6
# 10  11.0           Saquon Barkley  NYG   RB9  vs. JAC   5.0   25.0  12.6
# 14  15.0                Joe Mixon  CIN  RB10   at IND   5.0   31.0  15.2
# 15  16.0              Dalvin Cook  MIN  RB11   vs. SF   5.0   36.0  15.7
# 16  17.0             Alex Collins  BAL  RB12  vs. BUF   6.0   45.0  16.7
# 19  20.0            Jordan Howard  CHI  RB13    at GB   9.0   43.0  20.4
# 20  21.0          Devonta Freeman  ATL  RB14   at PHI  10.0   37.0  22.0
# 23  24.0             Lamar Miller  HOU  RB16    at NE  12.0   59.0  26.9
# 22  23.0             Kenyan Drake  MIA  RB15  vs. TEN  11.0   80.0  26.4
# 24  25.0             LeSean McCoy  BUF  RB17   at BAL  12.0   80.0  27.2
# 28  29.0            Royce Freeman  DEN  RB19  vs. SEA  11.0   55.0  31.1
# 27  28.0             James Conner  PIT  RB18   at CLE  11.0  127.0  28.4
# 29  30.0            Derrick Henry  TEN  RB20   at MIA   6.0   84.0  31.3
# 32  33.0          Jamaal Williams   GB  RB21  vs. CHI  14.0   69.0  33.6
# 33  34.0                Jay Ajayi  PHI  RB22  vs. ATL  12.0   68.0  34.5
# 37  38.0              Carlos Hyde  CLE  RB23  vs. PIT  21.0   62.0  39.4
# 40  41.0             Rex Burkhead   NE  RB24  vs. HOU  20.0   84.0  43.6
# 46  47.0               Dion Lewis  TEN  RB25   at MIA  26.0   75.0  48.9
# 49  50.0           Marshawn Lynch  OAK  RB26  vs. LAR  22.0  102.0  49.0
# 50  51.0            Peyton Barber   TB  RB27    at NO  29.0  122.0  51.2
# 56  57.0             Chris Carson  SEA  RB28   at DEN  34.0  107.0  61.4
# 58  59.0          Adrian Peterson  WAS  RB29   at ARI  35.0  113.0  62.5
# 60  61.0            Tevin Coleman  ATL  RB30   at PHI  30.0   96.0  64.2
#
#     Std Dev         Score Pos_Name
# 0       0.5      1.018234       RB
# 1       1.0      6.250000       RB
# 2       1.6     12.952689       RB
# 3       2.1     42.256855       RB
# 4       2.3     47.559795       RB
# 5       1.4     49.990874       RB
# 6       4.4    185.345500       RB
# 7       3.5    210.206312       RB
# 10      3.8    309.480214       RB
# 14      4.7    500.882784       RB
# 15      5.7    588.486809       RB
# 16      6.0    683.138194       RB
# 19      5.1    939.821601       RB
# 20      5.2   1103.689811       RB
# 23      7.9   2033.846187       RB
# 22      9.4   2136.838897       RB
# 24     11.7   2530.642160       RB
# 28      8.5   2819.877491       RB
# 27     16.4   3266.319052       RB
# 29     11.9   3379.575521       RB
# 32     11.2   3778.222814       RB
# 33     11.3   4001.081630       RB
# 37      8.9   4631.135063       RB
# 40     12.5   6720.908534       RB
# 46     11.5   8108.987639       RB
# 49     14.6   9174.208118       RB
# 50     14.1   9843.498473       RB
# 56     11.6  12840.021085       RB
# 58     14.5  14874.556847       RB
# 60     15.6  16279.173631       RB

# %%
tight_end()
# Out:
#       Rank Flex Position (RB/WR/TE)  Team   Pos      Opp  Best  Worst    Avg  \
# 11    12.0           Rob Gronkowski    NE   TE1  vs. HOU   4.0   51.0   14.4
# 43    44.0             Travis Kelce    KC   TE2   at LAC  23.0   90.0   46.1
# 47    48.0                Zach Ertz   PHI   TE3  vs. ATL  16.0   91.0   48.9
# 65    66.0             Jimmy Graham    GB   TE4  vs. CHI  37.0   95.0   68.9
# 69    70.0           Delanie Walker   TEN   TE5   at MIA  16.0   95.0   72.1
# 74    75.0             Kyle Rudolph   MIN   TE7   vs. SF  44.0  123.0   78.3
# 71    72.0               Greg Olsen  CAR    TE6  vs. DAL  41.0  131.0   75.2
# 82    83.0              Trey Burton   CHI   TE8    at GB  44.0  121.0   86.0
# 85    86.0              Jordan Reed   WAS   TE9   at ARI  42.0  124.0   88.1
# 97    98.0              Evan Engram   NYG  TE11  vs. JAC  64.0  136.0  101.3
# 95    96.0               Jack Doyle   IND  TE10  vs. CIN  55.0  146.0  100.0
# 104  105.0             Tyler Eifert   CIN  TE12   at IND  65.0  139.0  107.7
# 109  110.0              David Njoku   CLE  TE13  vs. PIT  63.0  147.0  113.7
# 113  114.0  Austin Seferian-Jenkins   JAC  TE14   at NYG  80.0  154.0  117.0
# 129  130.0               Jared Cook   OAK  TE17  vs. LAR  80.0  158.0  127.1
# 127  128.0            George Kittle    SF  TE15   at MIN  88.0  164.0  127.0
# 128  129.0              O.J. Howard    TB  TE16    at NO  73.0  165.0  127.6
# 133  134.0          Benjamin Watson    NO  TE19   vs. TB  82.0  181.0  130.8
# 131  132.0        Ricky Seals-Jones   ARI  TE18  vs. WAS  83.0  179.0  130.6
# 141  142.0               Eric Ebron   IND  TE20  vs. CIN  79.0  189.0  137.6
#
#      Std Dev         Score Pos_Name
# 11       6.4    524.583916       TE
# 43      10.6   6919.182464       TE
# 47      12.6   8487.953483       TE
# 65      14.3  17951.736401       TE
# 69      12.6  18452.524983       TE
# 74      12.0  21238.025951       TE
# 71      16.7  23109.679197       TE
# 82      16.8  30314.579146       TE
# 85      16.7  31718.310950       TE
# 97      14.5  39075.351361       TE
# 95      15.7  39623.225512       TE
# 104     15.9  46251.941616       TE
# 109     14.6  49396.634132       TE
# 113     15.0  53017.269026       TE
# 129     12.7  57569.566813       TE
# 127     14.0  60349.191991       TE
# 128     17.1  67328.572083       TE
# 133     15.8  68005.498968       TE
# 131     17.3  70942.976429       TE
# 141     18.5  81437.181024       TE

# %%
wide_r()
# Out:
#     Rank Flex Position (RB/WR/TE) Team   Pos      Opp  Best  Worst   Avg  \
# 9   10.0          DeAndre Hopkins  HOU   WR2    at NE   3.0   33.0  11.9
# 8    9.0            Antonio Brown  PIT   WR1   at CLE   2.0   99.0  11.4
# 13  14.0           Michael Thomas   NO   WR4   vs. TB   3.0   26.0  15.0
# 12  13.0               A.J. Green  CIN   WR3   at IND   2.0   31.0  14.9
# 17  18.0              Julio Jones  ATL   WR5   at PHI   3.0   31.0  17.3
# 18  19.0             Keenan Allen  LAC   WR6   vs. KC   3.0   29.0  19.4
# 21  22.0            Davante Adams   GB   WR7  vs. CHI  10.0   30.0  23.3
# 26  27.0             Stefon Diggs  MIN   WR9   vs. SF  19.0   38.0  28.1
# 25  26.0        Odell Beckham Jr.  NYG   WR8  vs. JAC  11.0   61.0  28.0
# 30  31.0         Larry Fitzgerald  ARI  WR10  vs. WAS  17.0   45.0  32.1
# 31  32.0              T.Y. Hilton  IND  WR11  vs. CIN  16.0   48.0  31.3
# 34  35.0              Chris Hogan   NE  WR12  vs. HOU  16.0   49.0  34.6
# 35  36.0              Tyreek Hill   KC  WR13   at LAC  12.0   58.0  35.9
# 36  37.0             Adam Thielen  MIN  WR14   vs. SF  25.0   58.0  38.1
# 38  39.0               Mike Evans   TB  WR15    at NO  15.0   68.0  39.9
# 39  40.0             Marvin Jones  DET  WR16  vs. NYJ  27.0   65.0  43.5
# 42  43.0            Brandin Cooks  LAR  WR18   at OAK  26.0   65.0  45.8
# 41  42.0              Golden Tate  DET  WR17  vs. NYJ  26.0   76.0  44.9
# 44  45.0         Demaryius Thomas  DEN  WR19  vs. SEA  22.0   66.0  46.4
# 45  46.0             Doug Baldwin  SEA  WR20   at DEN  23.0   81.0  46.4
# 48  49.0      JuJu Smith-Schuster  PIT  WR21   at CLE  32.0   93.0  49.0
# 52  53.0           Allen Robinson  CHI  WR23    at GB  32.0   70.0  51.6
# 51  52.0             Amari Cooper  OAK  WR22  vs. LAR  37.0   81.0  52.3
# 53  54.0            Jarvis Landry  CLE  WR24  vs. PIT  25.0   72.0  54.6
# 54  55.0         Emmanuel Sanders  DEN  WR25  vs. SEA  26.0   77.0  55.5
# 59  60.0              Cooper Kupp  LAR  WR28   at OAK  39.0   80.0  64.1
# 55  56.0              Corey Davis  TEN  WR26   at MIA  25.0  119.0  59.8
# 57  58.0         Michael Crabtree  BAL  WR27  vs. BUF  46.0  111.0  61.8
# 64  65.0          Jamison Crowder  WAS  WR32   at ARI  46.0   98.0  66.9
# 63  64.0             Kenny Stills  MIA  WR31  vs. TEN  40.0  108.0  66.6
#
#     Std Dev         Score Pos_Name
# 9       6.0    346.872242       WR
# 8      12.9    466.771744       WR
# 13      5.4    522.852752       WR
# 12      5.7    530.041610       WR
# 17      5.3    689.017323       WR
# 18      5.8    906.394907       WR
# 21      4.9   1201.738243       WR
# 26      4.1   1598.838392       WR
# 25      5.8   1888.122030       WR
# 30      5.3   2372.181964       WR
# 31      6.0   2399.740606       WR
# 34      6.8   3121.811341       WR
# 35      7.4   3505.942241       WR
# 36      6.7   3757.399322       WR
# 38      8.6   4668.689776       WR
# 39      6.9   4970.534119       WR
# 42      6.4   5306.656089       WR
# 41      7.0   5333.861101       WR
# 44      7.5   5896.123787       WR
# 45      9.3   6565.645580       WR
# 48      9.6   7439.226411       WR
# 52      7.9   7483.641056       WR
# 51      7.8   7639.249230       WR
# 53      8.7   8793.158706       WR
# 54      9.4   9443.867671       WR
# 59      7.7  11401.485037       WR
# 55     12.3  12541.657131       WR
# 57     11.0  12666.986064       WR
# 64      8.6  13125.064948       WR
# 63     11.3  14910.344577       WR

# %%
qb_data()
# Out:
#     Rank        Quarterbacks Team      Opp  Best  Worst   Avg  Std Dev  \
# 0    1.0       Aaron Rodgers   GB  vs. CHI   1.0    8.0   1.7      1.3
# 1    2.0           Tom Brady   NE  vs. HOU   1.0    6.0   2.6      1.1
# 2    3.0          Drew Brees   NO   vs. TB   1.0   16.0   3.3      2.2
# 3    4.0          Cam Newton  CAR  vs. DAL   1.0   11.0   4.3      2.1
# 4    5.0      Deshaun Watson  HOU    at NE   1.0    9.0   5.3      1.6
# 5    6.0    Matthew Stafford  DET  vs. NYJ   3.0   14.0   6.2      2.0
# 6    7.0        Kirk Cousins  MIN   vs. SF   2.0   15.0   7.4      2.0
# 7    8.0       Philip Rivers  LAC   vs. KC   3.0   21.0   8.0      2.7
# 8    9.0      Russell Wilson  SEA   at DEN   2.0   17.0   9.2      2.4
# 11  12.0          Jared Goff  LAR   at OAK   4.0   18.0  11.3      2.6
# 9   10.0         Andy Dalton  CIN   at IND   4.0   20.0  11.2      2.7
# 10  11.0         Andrew Luck  IND  vs. CIN   5.0   23.0  11.3      2.8
# 12  13.0      Marcus Mariota  TEN   at MIA  10.0   22.0  14.3      2.5
# 14  15.0           Matt Ryan  ATL   at PHI   8.0   22.0  16.1      2.6
# 13  14.0  Ben Roethlisberger  PIT   at CLE   5.0   26.0  14.5      4.5
# 15  16.0          Alex Smith  WAS   at ARI   4.0   27.0  16.2      3.3
# 16  17.0     Patrick Mahomes   KC   at LAC   9.0   25.0  17.4      3.4
# 19  20.0       Blake Bortles  JAC   at NYG  11.0   28.0  19.9      3.0
# 18  19.0        Dak Prescott  DAL   at CAR   9.0   26.0  18.9      3.8
# 17  18.0        Tyrod Taylor  CLE  vs. PIT  11.0   29.0  19.0      3.8
# 24  25.0      Mitch Trubisky  CHI    at GB  15.0   29.0  22.5      3.1
# 20  21.0     Jimmy Garoppolo   SF   at MIN   8.0   27.0  21.4      3.9
# 23  24.0          Nick Foles  PHI  vs. ATL  11.0   35.0  22.4      3.6
# 21  22.0         Case Keenum  DEN  vs. SEA  10.0   30.0  21.9      4.1
# 22  23.0        Sam Bradford  ARI  vs. WAS  13.0   29.0  23.4      3.6
# 28  29.0          Derek Carr  OAK  vs. LAR  18.0   31.0  27.1      2.6
# 25  26.0    Ryan Fitzpatrick   TB    at NO  16.0   31.0  25.8      3.3
# 29  30.0         Sam Darnold  NYJ   at DET  20.0   32.0  29.8      1.9
# 30  31.0         Eli Manning  NYG  vs. JAC  23.0   31.0  29.8      1.9
# 26  27.0      Ryan Tannehill  MIA  vs. TEN  13.0   31.0  26.2      3.2
# 27  28.0          Joe Flacco  BAL  vs. BUF  16.0   31.0  26.9      3.1
#
#           Score
# 0      3.295107
# 1      7.089948
# 2     16.152480
# 3     26.794556
# 4     35.531352
# 5     54.362369
# 6     77.442335
# 7    105.162731
# 8    131.123724
# 11   205.893938
# 9    206.118953
# 10   213.666238
# 12   323.327079
# 14   417.963566
# 13   446.007602
# 15   476.745935
# 16   558.261856
# 19   685.909440
# 18   696.330482
# 17   703.718552
# 24   891.345104
# 20   904.398535
# 23   952.022663
# 21   971.136233
# 22  1038.922053
# 28  1184.200543
# 25  1209.195109
# 29  1224.078665
# 30  1224.078665
# 26  1227.941202
# 27  1274.046875

# %%
dst_data()
# Out:
#     Rank            Team DST      Opp  Best  Worst   Avg  Std Dev       Score
# 0    1.0     Baltimore (BAL)  vs. BUF   1.0    2.0   1.2      0.4    0.910736
# 1    2.0    New Orleans (NO)   vs. TB   1.0   12.0   3.1      1.9   13.246471
# 2    3.0  Jacksonville (JAC)   at NYG   1.0    7.0   3.3      1.5   13.337472
# 3    4.0       Detroit (DET)  vs. NYJ   2.0   14.0   5.6      2.6   50.566481
# 4    5.0     Minnesota (MIN)   vs. SF   2.0   14.0   5.7      2.5   51.371201
# 5    6.0   Los Angeles (LAR)   at OAK   2.0   20.0   6.7      4.6   96.278324
# 6    7.0        Denver (DEN)  vs. SEA   5.0   12.0   8.2      2.3  101.974509
# 8    9.0      Carolina (CAR)  vs. DAL   4.0   15.0   9.7      2.5  148.769353
# 9   10.0   Los Angeles (LAC)   vs. KC   4.0   14.0   9.9      2.5  154.967417
# 7    8.0    Pittsburgh (PIT)   at CLE   1.0   15.0   9.4      3.2  158.063173
# 10  11.0     Tennessee (TEN)   at MIA   7.0   21.0  11.4      3.3  236.084064
# 12  13.0    New England (NE)  vs. HOU   6.0   20.0  11.7      3.6  259.730513
# 11  12.0      Green Bay (GB)  vs. CHI   5.0   19.0  12.1      3.8  285.405632
# 13  14.0  Philadelphia (PHI)  vs. ATL   4.0   21.0  13.5      3.3  331.073566
# 14  15.0    Cincinnati (CIN)   at IND   6.0   21.0  14.4      3.4  382.352948
# 16  17.0       Arizona (ARI)  vs. WAS  10.0   23.0  17.5      2.6  493.813287
# 15  16.0       Atlanta (ATL)   at PHI   6.0   25.0  16.2      4.2  537.841952
# 18  19.0       Seattle (SEA)   at DEN   9.0   22.0  18.4      2.8  566.519237
# 20  21.0      New York (NYG)  vs. JAC  13.0   27.0  20.4      3.0  720.810264
# 21  22.0       Buffalo (BUF)   at BAL  13.0   26.0  19.7      3.7  746.506020

# %%
k_data()
# Out:
#     Rank             Kickers Team      Opp  Best  Worst   Avg  Std Dev  \
# 0    1.0  Stephen Gostkowski   NE  vs. HOU   1.0    8.0   2.4      1.3
# 2    3.0       Justin Tucker  BAL  vs. BUF   1.0   10.0   2.5      2.0
# 1    2.0       Greg Zuerlein  LAR   at OAK   1.0    5.0   2.9      1.2
# 3    4.0            Wil Lutz   NO   vs. TB   1.0   11.0   3.7      2.0
# 4    5.0         Matt Prater  DET  vs. NYJ   1.0   12.0   5.1      1.9
# 5    6.0        Mason Crosby   GB  vs. CHI   4.0   14.0   7.4      2.5
# 6    7.0        Jake Elliott  PHI  vs. ATL   3.0   19.0   9.0      2.9
# 8    9.0         Matt Bryant  ATL   at PHI   3.0   18.0  10.4      3.6
# 10  11.0         Graham Gano  CAR  vs. DAL   7.0   20.0  11.4      2.6
# 9   10.0       Chris Boswell  PIT   at CLE   5.0   20.0  10.2      4.3
# 7    8.0       Caleb Sturgis  LAC   vs. KC   5.0   27.0  10.6      5.0
# 12  13.0     Harrison Butker   KC   at LAC   5.0   19.0  12.6      2.7
# 11  12.0      Adam Vinatieri  IND  vs. CIN   1.0   23.0  11.7      3.7
# 14  15.0          Josh Lambo  JAC   at NYG   9.0   20.0  13.9      2.6
# 13  14.0      Daniel Carlson  MIN   vs. SF   5.0   22.0  12.8      4.3
# 15  16.0         Ryan Succop  TEN   at MIA   8.0   20.0  14.6      2.7
# 18  19.0         Phil Dawson  ARI  vs. WAS  15.0   23.0  18.7      2.0
# 16  17.0     Brandon McManus  DEN  vs. SEA   4.0   23.0  16.5      4.1
# 20  21.0    Ka'imi Fairbairn  HOU    at NE   9.0   26.0  19.8      3.0
# 17  18.0       Randy Bullock  CIN   at IND   9.0   30.0  18.8      3.9
#
#          Score
# 0     6.567410
# 2     8.838835
# 1     9.212693
# 3    19.360584
# 4    35.852311
# 5    86.583162
# 6   137.938030
# 8   205.219171
# 10  209.554203
# 9   215.741936
# 7   251.244598
# 12  260.869300
# 11  263.313172
# 14  311.541764
# 13  339.745855
# 15  350.257621
# 18  494.536341
# 16  551.264235
# 20  679.033199
# 17  697.988074
